# %% [markdown]
# # Apriori Algorithm for Recommending Artist for Spotify Playlist

# %% [markdown]
# ## Spotify Dataset
# ----

# %%
# Import libraries
import pandas as pd
import numpy as np
import random
import unicodedata

# %%
# Load the original dataset
spotify = pd.read_csv("spotify_dataset.csv",
                   names = ["user_id", "artistname", "trackname", "playlistname"], 
                   sep = '\",\"', 
                   engine = 'python',
                   skiprows = 1).dropna().reset_index(drop=True)
spotify
# Out:
#                                     user_id                        artistname  \
# 0         "9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1         "9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2         "9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3         "9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4         "9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# ...                                     ...                               ...
# 12868976  "2302bf9c64dc63d88a750215ed187f2c                       Mötley Crüe
# 12868977  "2302bf9c64dc63d88a750215ed187f2c                       John Lennon
# 12868978  "2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12868979  "2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12868980  "2302bf9c64dc63d88a750215ed187f2c                          Skid Row
#
#                                                   trackname     playlistname
# 0                      (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010"
# 1         (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010"
# 2                                          7 Years Too Late  HARD ROCK 2010"
# 3                                     Accidents Will Happen  HARD ROCK 2010"
# 4                                                    Alison  HARD ROCK 2010"
# ...                                                     ...              ...
# 12868976                                          Wild Side          iPhone"
# 12868977                                              Woman          iPhone"
# 12868978                        You Don't Know How It Feels          iPhone"
# 12868979                                       You Wreck Me          iPhone"
# 12868980                                    Youth Gone Wild          iPhone"
#
# [12868981 rows x 4 columns]

# %% [markdown]
# ### Data Cleaning

# %%
# Fix the artist names removing characters
artistname = []
for i in range(len(spotify)):
    artistname.append(unicodedata.normalize('NFKD',spotify["artistname"][i]).encode("ascii","ignore").decode('ascii'))

spotify["artistname"] = artistname
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a79e67f87501> in <module>
#       1 # Fix the artist names removing characters
#       2 artistname = []
# ----> 3 for i in range(len(spotify)):
#       4     artistname.append(unicodedata.normalize('NFKD',spotify["artistname"][i]).encode("ascii","ignore").decode('ascii'))
#       5
#
# NameError: name 'spotify' is not defined

# %%
# Fix the strings for dataset, removing quotation marks
spotify['user_id'] = spotify['user_id'].str.replace('"', '')
spotify['artistname'] = spotify['artistname'].str.replace('"', '')
spotify['trackname'] = spotify['trackname'].str.replace('"', '')
spotify['playlistname'] = spotify['playlistname'].str.replace('"', '')

# %%
# Fix the empty string and string nan, removing frmo dataset
spotify = spotify[(spotify['user_id'] != "")]
spotify = spotify[(spotify['artistname'] != "")]
spotify = spotify[(spotify['trackname'] != "")]
spotify = spotify[(spotify['playlistname'] != "")]

spotify = spotify[(spotify['user_id'] != "null")]
spotify = spotify[(spotify['artistname'] != "null")]
spotify = spotify[(spotify['trackname'] != "null")]
spotify = spotify[(spotify['playlistname'] != "null")]

# %%
# Checker to make sure all empty values are gone
spotify[(spotify["playlistname"] == "null") | (spotify["playlistname"] == "")]
# Out:
# Empty DataFrame
# Columns: [user_id, artistname, trackname, playlistname]
# Index: []

# %%
# checking to see the string manipulation worked
spotify
# Out:
#                                    user_id                        artistname  \
# 0         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2         9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# ...                                    ...                               ...
# 12868976  2302bf9c64dc63d88a750215ed187f2c                       Motley Crue
# 12868977  2302bf9c64dc63d88a750215ed187f2c                       John Lennon
# 12868978  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12868979  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12868980  2302bf9c64dc63d88a750215ed187f2c                          Skid Row
#
#                                                   trackname    playlistname
# 0                      (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1         (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                          7 Years Too Late  HARD ROCK 2010
# 3                                     Accidents Will Happen  HARD ROCK 2010
# 4                                                    Alison  HARD ROCK 2010
# ...                                                     ...             ...
# 12868976                                          Wild Side          iPhone
# 12868977                                              Woman          iPhone
# 12868978                        You Don't Know How It Feels          iPhone
# 12868979                                       You Wreck Me          iPhone
# 12868980                                    Youth Gone Wild          iPhone
#
# [12868981 rows x 4 columns]

# %%
# Export clean dataset
spotify.to_csv('spotify_clean.csv', sep = ";", index=False)

# %% [markdown]
# ### Dataset Analysis

# %%
# Load the clean dataset
spotify = pd.read_csv("spotify_clean.csv", sep = ";", header = 0)
spotify
# Out:
#                                    user_id                        artistname  \
# 0         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# 1         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 2         9cc0cfd4d7d7885102480dd99e7a90d6                      Tiffany Page
# 3         9cc0cfd4d7d7885102480dd99e7a90d6  Elvis Costello & The Attractions
# 4         9cc0cfd4d7d7885102480dd99e7a90d6                    Elvis Costello
# ...                                    ...                               ...
# 12865156  2302bf9c64dc63d88a750215ed187f2c                       Motley Crue
# 12865157  2302bf9c64dc63d88a750215ed187f2c                       John Lennon
# 12865158  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12865159  2302bf9c64dc63d88a750215ed187f2c                         Tom Petty
# 12865160  2302bf9c64dc63d88a750215ed187f2c                          Skid Row
#
#                                                   trackname    playlistname
# 0                      (The Angels Wanna Wear My) Red Shoes  HARD ROCK 2010
# 1         (What's So Funny 'Bout) Peace, Love And Unders...  HARD ROCK 2010
# 2                                          7 Years Too Late  HARD ROCK 2010
# 3                                     Accidents Will Happen  HARD ROCK 2010
# 4                                                    Alison  HARD ROCK 2010
# ...                                                     ...             ...
# 12865156                                          Wild Side          iPhone
# 12865157                                              Woman          iPhone
# 12865158                        You Don't Know How It Feels          iPhone
# 12865159                                       You Wreck Me          iPhone
# 12865160                                    Youth Gone Wild          iPhone
#
# [12865161 rows x 4 columns]

# %%
print("number of unique users:", len(list(spotify.user_id.unique())))
print("number of unique artist:", len(list(spotify.artistname.unique()))) 
print("number of unique playlists:", len(list(spotify.playlistname.unique())))
# Out:
# number of unique users: 15913
# number of unique artist: 288158
# number of unique playlists: 157289

# %%
# Count the number of unique artist in each playlist
uniqueArtisit_playlist = pd.DataFrame({'NumArtistInPlaylist' : 
                                       spotify.groupby(['playlistname'])[
                                           'artistname'].nunique().sort_values(ascending=False)}).reset_index()
uniqueArtisit_playlist.describe()
# Out:
#        NumArtistInPlaylist
# count        157289.000000
# mean             22.967156
# std             214.379121
# min               1.000000
# 25%               1.000000
# 50%               3.000000
# 75%              20.000000
# max           76500.000000

# %%
# Count the occurence of each artist
uniqueArtisit = pd.DataFrame({'count':spotify.groupby('artistname')[
                                        'artistname'].count().sort_values(ascending=False)}).reset_index()
uniqueArtisit.describe()
# Out:
#                count
# count  288158.000000
# mean       44.646205
# std       439.937957
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        10.000000
# max     36086.000000

# %%
# how many playlist contain only one artist
uniqueArtisit_playlist[uniqueArtisit_playlist["NumArtistInPlaylist"] == 1]
# Out:
#                                              playlistname  NumArtistInPlaylist
# 91990                                        Fat Boy Slim                    1
# 91991   Eels — Meet The EELS: Essential EELS 1996-2006...                    1
# 91992                      Ellie Goulding – Bright Lights                    1
# 91993                                               'Mats                    1
# 91994                              Fat Jon – afterthought                    1
# ...                                                   ...                  ...
# 157284                    Longpigs — The Sun Is Often Out                    1
# 157285                                           Longview                    1
# 157286           Lonnie Johnson – Blues By Lonnie Johnson                    1
# 157287  Lonnie Liston Smith - Explorations: The Columb...                    1
# 157288                      Master p – Good Side/Bad Side                    1
#
# [65299 rows x 2 columns]

# %% [markdown]
# ## The Apriori Algorithm Implementation

# %% [markdown]
# ### Data Setup
# ---

# %%
# summary data about the dataframe
uniqueArtisit_playlist.describe()
# Out:
#        NumArtistInPlaylist
# count        157289.000000
# mean             22.967156
# std             214.379121
# min               1.000000
# 25%               1.000000
# 50%               3.000000
# 75%              20.000000
# max           76500.000000

# %%
# Subset of the data for number of unique artists in each playlist
uniqueArtist_subset = uniqueArtisit_playlist[(uniqueArtisit_playlist['NumArtistInPlaylist'] > 3) & (uniqueArtisit_playlist['NumArtistInPlaylist'] < 10)]
uniqueArtist_subset
# Out:
#                          playlistname  NumArtistInPlaylist
# 60291                        toteking                    9
# 60292                       valentine                    9
# 60293         Mom & Dad's Kinda Music                    9
# 60294                   2 min 160 bpm                    9
# 60295                 MIXY MIX APR 14                    9
# ...                               ...                  ...
# 77310                         Roar같은곡                    4
# 77311   Prince – The Hits/The B-Sides                    4
# 77312  Agent Sasco – Shellings Riddim                    4
# 77313                      9th Wonder                    4
# 77314              Productivity Beats                    4
#
# [17024 rows x 2 columns]

# %%
# For the subset of number of artist in each playlist
# Group Rows on 'playlistname' column and get List for 'artistname' column
spotifyML = spotify[spotify['playlistname'].isin(uniqueArtist_subset['playlistname'])].groupby('playlistname')['artistname'].agg(['unique']).reset_index()
spotifyML
# Out:
#                               playlistname  \
# 0                                    Frida
# 1       #glgsongaday Day 1:  New Beginning
# 2                                        2
# 3                            80s Gung 2012
# 4                ASLA Birthday April 13/13
# ...                                    ...
# 17019                                    😴
# 17020                                  🙌🇫🇷
# 17021                                    🚀
# 17022                                    🚇
# 17023                                    🚙
#
#                                                   unique
# 0      [Elliot Goldenthal, Traditional, Luis Arcaraz ...
# 1      [The Olivia Tremor Control, David Gray, Lily A...
# 2      [Kanye West, D.J. Stevie Tee, K's Choice, Done...
# 3      [Michael McDonald, Russ Ballard, Foreigner, Fl...
# 4      [The Black Eyed Peas, Swedish House Mafia, Mad...
# ...                                                  ...
# 17019  [The 1975, Phaeleh, The xx, Deptford Goth, Sir...
# 17020  [Phoenix, Tahiti 80, Breakbot, Uffie, Daft Pun...
# 17021  [Kasabian, Death From Above 1979, The Futurehe...
# 17022  [Koan Sound, Future Islands, Classixx, Seapony...
# 17023  [Rihanna, The Weeknd, alt-J, Dillon Francis, E...
#
# [17024 rows x 2 columns]

# %%
# For the entire dataset
# Group Rows on 'playlistname' column and get List for 'artistname' column
#spotifyML = spotify.groupby('playlistname')['artistname'].agg(['unique']).reset_index()
spotifyML
# Out:
#                               playlistname  \
# 0                                    Frida
# 1       #glgsongaday Day 1:  New Beginning
# 2                                        2
# 3                            80s Gung 2012
# 4                ASLA Birthday April 13/13
# ...                                    ...
# 17019                                    😴
# 17020                                  🙌🇫🇷
# 17021                                    🚀
# 17022                                    🚇
# 17023                                    🚙
#
#                                                   unique
# 0      [Elliot Goldenthal, Traditional, Luis Arcaraz ...
# 1      [The Olivia Tremor Control, David Gray, Lily A...
# 2      [Kanye West, D.J. Stevie Tee, K's Choice, Done...
# 3      [Michael McDonald, Russ Ballard, Foreigner, Fl...
# 4      [The Black Eyed Peas, Swedish House Mafia, Mad...
# ...                                                  ...
# 17019  [The 1975, Phaeleh, The xx, Deptford Goth, Sir...
# 17020  [Phoenix, Tahiti 80, Breakbot, Uffie, Daft Pun...
# 17021  [Kasabian, Death From Above 1979, The Futurehe...
# 17022  [Koan Sound, Future Islands, Classixx, Seapony...
# 17023  [Rihanna, The Weeknd, alt-J, Dillon Francis, E...
#
# [17024 rows x 2 columns]

# %%
# Prepare the data for model
# Store the item sets as tuples of strings in a list
listArtist = []
for i in range(len(spotifyML)):
    listArtist.append(tuple(spotifyML["unique"].loc[i]))

# %%
# List output
listArtist
# Out:
# [('Elliot Goldenthal',
#   'Traditional',
#   'Luis Arcaraz Torras',
#   'Los Cojolites',
#   'Luis Mars',
#   'Tomas Mendez'),
#  ('The Olivia Tremor Control',
#   'David Gray',
#   'Lily Allen',
#   'Little Joy',
#   'Husker Du',
#   'Arcade Fire',
#   'The The',
#   'The Mountain Goats'),
#  ('Kanye West',
#   'D.J. Stevie Tee',
#   "K's Choice",
#   'Done Again',
#   'Space',
#   'Stuph'),
#  ('Michael McDonald',
#   'Russ Ballard',
#   'Foreigner',
#   'Fleetwood Mac',
#   'Billy Ocean',
#   'Eric Carmen',
#   'The Doobie Brothers'),
#  ('The Black Eyed Peas',
#   'Swedish House Mafia',
#   'Madonna',
#   'Justin Timberlake',
#   'One Direction',
#   'will.i.am',
#   'Disclosure'),
#  ('Unknown', 'Trazan', 'Gullan Bornemark', 'Lasse Berghagen'),
#  ('Megadeth',
#   'Black Sabbath',
#   'White Zombie',
#   'Kasabian',
#   'Classic Rock Monsters',
#   'Bruce Dickinson',
#   'Jack White'),
#  ('Jay McShann',
#   'Lucky Millinder',
#   'Mongo Santamaria',
#   'Oscar Peterson',
#   'Sonny Terry',
#   'Chet Baker'),
#  ('Patrick Doyle',
#   'Julie Fowlis',
#   'Mumford & Sons',
#   'Emma Thompson',
#   'Carey Wilson'),
#  ('Phil Collins',
#   'Jack Johnson',
#   'Simon & Garfunkel',
#   'Mumford & Sons',
#   'Carla Bruni',
#   "Rosie O'Donnell"),
#  ('Brad Paisley',
#   'Randy Newman',
#   'Rascal Flatts',
#   'Hank Williams',
#   'James Taylor',
#   'Sheryl Crow',
#   'John Mayer',
#   'The Chords'),
#  ('Avicii',
#   'Calvin Harris',
#   'Skrillex',
#   'Zedd',
#   'David Guetta',
#   'Afrojack',
#   "Daddy's Groove - David Guetta",
#   'Avicii - David Guetta',
#   'Snoop Dogg'),
#  ('Leonard Cohen',
#   'Annie Lennox',
#   'Eric Clapton',
#   'Frank Sinatra',
#   'Tony Bennett',
#   'Paul McCartney'),
#  ('Jakobin',
#   'Alex Neivel',
#   'TJ Kong',
#   'Nathan G',
#   'Edmund',
#   'Fred Everything',
#   'Kerri Chandler',
#   'Scope',
#   'Matthias Vogt'),
#  ('Miguel Campello', 'Mario Diaz', 'Elbicho', 'Los Chunguitos'),
#  ('Jean-Philippe Collard',
#   'Jean-Philippe Collard/Bruno Rigutto',
#   'Gabriel Faure',
#   'Esteban Sanchez',
#   'David Jalbert',
#   'Vlado Perlemuter'),
#  ('Ravinrda Sathe',
#   'Pandit Jasraj',
#   'Sri Ganapathy Sachchidananda Swamiji',
#   'Edo & Jo',
#   'Gayatri Mantra',
#   'Indiajiva',
#   'Adham Shaikh',
#   'Suresh Wadkar'),
#  ('Hans Zimmer', 'Klaus Badelt', 'Lisa Gerrard', 'Djivan Gasparyan'),
#  ('Bhai Nirmal Singh Khalsa',
#   'Bhai Gurmej Singh Ragi',
#   'Bhai Ravinder Singh Ragi',
#   'Bhai Hari Singh Ragi',
#   'Bhai Sarabjeet Singh',
#   'Bhai Harbans Singh Ji'),
#  ('Clarke Thorell',
#   'Linda Hart',
#   'Dick Latessa',
#   'Mary Bond Davis',
#   'Laura Bell Bundy',
#   'Marissa Jaret Winokur',
#   'Matthew Morrison',
#   'Corey Reynolds',
#   'Jackie Hoffman'),
#  ('Michael Chance/Christopher Wilson',
#   'John Dowland',
#   'Fretwork',
#   'Michael Chance',
#   'Christopher Wilson',
#   'Fretwork/Christopher Wilson'),
#  ('Miles Davis',
#   'John Coltrane',
#   'Herbie Hancock',
#   'Django Reinhardt',
#   'Dave Brubeck',
#   'Yves Montand',
#   'Paul Desmond'),
#  ('Washed Out',
#   'Marilyn Manson',
#   'Peaches',
#   'Ke$ha',
#   'Daft Punk',
#   'Lady Gaga',
#   'Charli XCX',
#   'Imagine Dragons'),
#  ('De Vrolijke Mereltjes',
#   'Combo Lex van Veen',
#   'De Gouden Nachtegaaltjes',
#   'De Topkids'),
#  ('Frank Fernandez',
#   'Pancho Amat Y El Cabildo Del Son',
#   'Ivett Cepeda',
#   'Jessica Rodriguez',
#   'Buena Fe',
#   'Haydee Milanes',
#   'Kalunga',
#   'Carlos Varela',
#   'Pablo Milanes'),
#  ('Meryl Streep',
#   'Christine Baranski',
#   'Amanda Seyfried',
#   'Dominic Cooper',
#   'Colin Firth',
#   'Pierce Brosnan',
#   'Julie Walters',
#   'Cast Of Mamma Mia The Movie'),
#  ('Fergie', 'Emeli Sande', 'Sia', 'Bryan Ferry', 'Coco O.', 'Lana Del Rey'),
#  ('Michael Murphey',
#   'David Bromberg Band',
#   "Ramblin' Jack Elliott",
#   'Michael Martin Murphey',
#   'Willie Nelson',
#   'Jimmie Spheeris',
#   'Doug Kershaw'),
#  ('Space Raiders', 'La Pulqueria', 'Daniel Higienico', 'Eskorzo'),
#  ('Bill Elm & Woody Jackson',
#   'William Elliot Whitmore',
#   'Jamie Lidell',
#   'Ashtar Command',
#   'Jose Gonzalez'),
#  ('Christian Zacharias',
#   'Martha Argerich',
#   'Domenico Scarlatti',
#   'Murray Perahia',
#   'Vladimir Horowitz',
#   'Mikhail Pletnev'),
#  ('Ne-Yo',
#   'Sofia Karlberg',
#   'Teyana Taylor',
#   'Beyonce',
#   'The Weeknd',
#   'Annie Lennox',
#   'Drake',
#   'Frank Ocean',
#   'Lana Del Rey'),
#  ("Brian D'Arcy James",
#   'Daniel Breaker',
#   'John Tartaglia',
#   'Leah Greenhaus',
#   'Sutton Foster',
#   'Christopher Sieber'),
#  ('Jonathan Groff',
#   'John Gallagher, Jr.',
#   'Brian Johnson',
#   'Lea Michele',
#   'Lilli Cooper',
#   'Lauren Pritchard',
#   'Jonathan B. Wright'),
#  ('Gold Zebra', 'Hercules & Love Affair', 'The Antlers', 'FKA twigs'),
#  ('Fergie',
#   'will.i.am',
#   'Sia',
#   'Jack White',
#   'Bryan Ferry',
#   'JAY Z',
#   'The xx',
#   'Coco O.',
#   'Lana Del Rey'),
#  ('Marc Russo',
#   'Jerry Martin',
#   'Kirk Casey',
#   'Dix Bruce',
#   'Anna Karney',
#   'Kent Jolly',
#   'Francois La Fleur',
#   'Robi Kauker'),
#  ('Rumbanella Band',
#   'Wendo Kolosoy',
#   'Likembe Geant',
#   'Victoria Bakolo Miziki'),
#  ('Alice In Chains',
#   'Circa Survive',
#   'Jerry Cantrell',
#   'MUTEMATH',
#   'Sara Bareilles',
#   'The Dear Hunter',
#   'These Green Eyes',
#   'Foo Fighters'),
#  ('Radiohead',
#   'Nirvana',
#   'Funeral For A Friend',
#   'The Chariot',
#   'Red Hot Chili Peppers',
#   'Bon Iver'),
#  ('Bahamas',
#   'Passion Pit',
#   'Ezra Vine',
#   'St. Vincent',
#   'The New Basement Tapes',
#   'Vance Joy',
#   'Saint Motel',
#   'I LOVE MAKONNEN',
#   'tUnE-yArDs'),
#  ('Joel Grey',
#   'Idina Menzel',
#   'Norbert Leo Butz',
#   'Kristin Chenoweth',
#   'Christopher Fitzgerald',
#   'William Youmans',
#   'Carole Shelley'),
#  ('Andy Williams', 'Sufjan Stevens', 'Bing Crosby', 'Vince Guaraldi Trio'),
#  ('Estopa',
#   'Melendi',
#   'Estopa - Voces De Ultrarumba',
#   'Estopa - Voces de ultratumba'),
#  ('Lil Wayne',
#   'Busta Rhymes',
#   'JAY Z',
#   'Pharrell Williams',
#   'Missy Elliott',
#   'Clipse',
#   'Q-Tip',
#   'Kelis',
#   'N.E.R.D.'),
#  ('Aretha Franklin',
#   'Big Bad Voodoo Daddy',
#   'Anni Anderson & Maurice Dean',
#   'The Andrews Sisters',
#   'Dean Martin'),
#  ('Imagine Dragons',
#   'New Politics',
#   'Augustana',
#   'Sufjan Stevens',
#   'Peter Bradley Adams',
#   'LCD Soundsystem',
#   'Magic Man'),
#  ('Ben Howard', 'James Vincent McMorrow', 'The Antlers', 'Bon Iver'),
#  ('Pinback', 'The xx', 'Yeah Yeah Yeahs', 'Caribou'),
#  ('New Order',
#   'Pet Shop Boys',
#   'The Smiths',
#   'Morrissey',
#   'The Coral',
#   'Primal Scream',
#   'Echo And The Bunnymen',
#   "Ariel Pink's Haunted Graffiti",
#   'Happy Mondays'),
#  ('Yeasayer',
#   'Giorgio Moroder',
#   'Rinder & Lewis',
#   'Fever Ray & The Subliminal Kid',
#   'Arthur Russell',
#   'Fever Ray',
#   'The Very Best'),
#  ('Gold Panda',
#   'Bernard Fevre',
#   'Nathan Kowald',
#   'Das Moth',
#   'Totally Enormous Extinct Dinosaurs'),
#  ('Oliver Huntemann',
#   'Giorgio Moroder',
#   'Diamond Version',
#   'Rrose',
#   'Padded Cell',
#   'Byetone'),
#  ('Devine & Statton',
#   'Explosions in the Sky',
#   'Camille',
#   'The Field Mice',
#   'Asobi Seksu'),
#  ('Outernationals', 'Donna Summer', 'Lindstrm', 'Underworld'),
#  ('Nine Inch Nails',
#   'New Fast Automatic Daffodils',
#   'Curve',
#   'Black Grape',
#   'Denise Johnson',
#   'Billy Bragg',
#   'The Prodigy',
#   'Inspiral Carpets',
#   'Frankie Goes To Hollywood'),
#  ("I Love You But I've Chosen Darkness",
#   'Badly Drawn Boy',
#   'Gorillaz',
#   'Adamski vs. Killers',
#   'Air',
#   'Marit Bergman Vs. Justus Kohncke'),
#  ('Earlimart',
#   'The Beatles',
#   'Bright Eyes',
#   'The Arcade Fire',
#   'The Postal Service',
#   'Dntel'),
#  ('Patsy Cline',
#   'Willie Nelson',
#   'George Jones',
#   'Merle Haggard',
#   'Ernest Tubb',
#   'Carl Smith',
#   'George Jones and Melba Montgomery'),
#  ('Ramin Djawadi',
#   'The Good Men',
#   'Danny Elfman',
#   'Jeff van Dyck',
#   'Imagine Dragons',
#   'Sascha Dikiciyan'),
#  ('Olly Murs',
#   'Sam Smith',
#   'Marvin Gaye',
#   'You Me At Six',
#   'Bette Midler',
#   'A Day To Remember',
#   'Barry White'),
#  ('Alter Bridge',
#   'September When',
#   'Captain Jack',
#   'Sash!',
#   'The Pogues',
#   'Marillion',
#   'Darude',
#   'Volbeat',
#   'Franz Ferdinand'),
#  ('Slipknot',
#   'Dead Fish',
#   'Slash',
#   'Rage Against The Machine',
#   'Boys Bad News'),
#  ('R.E.M.',
#   'Daniel Johnston',
#   'Lloyd Cole',
#   'Beck',
#   'The Young Fresh Fellows',
#   'X'),
#  ('Murs', 'Dumbfoundead', 'Watsky', 'Atmosphere', 'Aesop Rock', 'Felt'),
#  ('Daryl Hall & John Oates',
#   'Bruce Springsteen',
#   'Moon Mullican',
#   'The Isley Brothers'),
#  ('Reincidentes', 'Extremoduro', 'Leon Benavente', 'Vetusta Morla'),
#  ('Frank Zappa',
#   'Wanda Jackson',
#   'Minutemen',
#   'Karen O',
#   'Roger Alan Wade',
#   'Davy Graham',
#   'Willie Nelson',
#   'Alexandre Desplat'),
#  ("Sinead O'Connor",
#   'Ane Brun',
#   'Zee Avi',
#   'Hot Chip',
#   'Eagles Of Death Metal',
#   'Soulwax'),
#  ('Mary Mary', 'Drake', 'Nicki Minaj', 'Bing Crosby', 'Fun.', 'Rihanna'),
#  ('Esham', 'NATAS', 'Natas', 'Kid Rock', 'The Dayton Family'),
#  ('Benny Benassi',
#   'Becky G',
#   'Flo Rida',
#   'French Montana',
#   'Skrillex',
#   'Thomas Gold feat. Kaelyn Behr',
#   'Calvin Harris'),
#  ('The Decemberists',
#   'Ben Folds',
#   'Liz Phair',
#   'The Jesus And Mary Chain',
#   'Of Montreal'),
#  ('C2C',
#   'Norlie & KKV',
#   'Alexandra Stan',
#   'Freddy Kalas',
#   'Cir.Cuz',
#   'OnklP & De Fjerne Slektningene',
#   'Maroon 5',
#   'Mark Ronson',
#   'Christian Walz'),
#  ('Afro Blue',
#   'Gonjasufi',
#   'The Psychedelic Aliens',
#   'Lee Scratch Perry',
#   'Massive Attack',
#   'Allen Stone',
#   'Hypnotic Brass Ensemble',
#   'Common',
#   'Dub Colossus'),
#  ('Sia', 'Christina Aguilera', 'Rihanna', 'Celine Dion', 'David Guetta'),
#  ("The B-52's", 'Balthazar', 'SX', "It's A Cover Up"),
#  ('Robbie Williams',
#   'The Shadows',
#   'Robyn',
#   'ABBA',
#   'Lisa Nilsson',
#   'Ted Gardestad',
#   'Di Leva'),
#  ('Oasis',
#   'The Cure',
#   'Mazzy Star',
#   'Radiohead',
#   'Primal Scream',
#   'Counting Crows',
#   'The Bluetones',
#   '4 Non Blondes'),
#  ('David Crowder Band',
#   'Sufjan Stevens',
#   'Ascend The Hill',
#   'Jeremy Camp',
#   'Daniel Martin Moore',
#   'Benjamin Dunn And Friends',
#   'Vince Gill',
#   'Jadon Lavik'),
#  ('Dr. Hook',
#   'Thau',
#   'Dire Straits',
#   'Faith No More',
#   'Queen',
#   'Weezer',
#   'The Band',
#   'Tenacious D'),
#  ('Zedd ft Foxes',
#   'The xx',
#   'Goldroom feat. Chela',
#   'Liar',
#   'India Martinez',
#   'Lana Del Rey'),
#  ('Bokoesam',
#   'D-Double',
#   "Lil' Kleine",
#   'Ronnie Flex',
#   'SFB',
#   'Jonna Fraser',
#   'Frenna',
#   'Lijpe',
#   'Ares'),
#  ('Cyril Hanouna',
#   'The Offspring',
#   'Adrien Gallo',
#   'James Bay',
#   'Marina Kaye',
#   'alt-J',
#   'Mina Tindle',
#   'Vianney'),
#  ('Erasure', 'alt-J', 'Pixies', 'Givers', 'The Virgins'),
#  ('Wiz Khalifa', 'Mac Miller', 'Donora', 'Vali'),
#  ('Coldplay', 'Madeon', 'Don Diablo', 'The Script'),
#  ('Azealia Banks',
#   'Madonna',
#   'The Black Eyed Peas',
#   'RuPaul',
#   'Britney Spears',
#   'Junior Senior',
#   'Ashlee Simpson'),
#  ('Lost Frequencies',
#   'Kyla La Grange',
#   'Kygo',
#   'Klingande',
#   'CUT_',
#   'Lilly Wood and The Prick',
#   'Ed Sheeran',
#   'Robin Schulz'),
#  ('Cross Canadian Ragweed',
#   'Josh Abbott Band',
#   'Aaron Watson',
#   'Randy Rogers Band',
#   'Eli Young Band',
#   'Kyle Park',
#   'Brandon Rhyder',
#   'Honeybrowne',
#   'Bart Crow Band'),
#  ('Busta Rhymes',
#   'Mavado',
#   'Mr. Vegas',
#   'Bunji Garlin',
#   'RDX',
#   'Konshens',
#   'Charly Black'),
#  ('Jessie J', 'Sia', 'Edson Pride', 'Thomas Gold', 'Rihanna'),
#  ('Fifth Harmony',
#   "Destiny's Child",
#   'Rihanna',
#   'Beyonce',
#   'Alicia Keys',
#   'Missy Elliott'),
#  ('Tiny Moving Parts',
#   'Artifex Pereo',
#   'Whirr',
#   'Dance Gavin Dance',
#   'Weatherbox',
#   'American Football',
#   'Old Gray',
#   'Balance And Composure',
#   'Dowsing'),
#  ('Air',
#   'Morcheeba',
#   'Telepopmusik',
#   'Gostan',
#   'Royksopp',
#   'Tez Cadey',
#   'The Shins',
#   'Chilly Gonzales',
#   'Four Tet'),
#  ('2Pac', 'Fugees', 'LL Cool J', 'Blackstreet', 'Nas'),
#  ('Proyecto Uno',
#   'El General',
#   'K7',
#   'Sandy & Papo',
#   'Los Amigos Invisibles',
#   'C & C Music Factory',
#   'Haddaway'),
#  ('Donny Hathaway',
#   'Indochine',
#   'James Bay',
#   'Gramatik',
#   'Theophilus London',
#   'Purity Ring'),
#  ('The Motion Sick', 'Eels', 'Elvis Costello & The Attractions', 'Madonna'),
#  ('Joni Mitchell',
#   'Spain',
#   'Norma Waterson',
#   'Gwyneth & Monko',
#   'Billie Holiday',
#   'Johnny Hartman',
#   'Johnny Cash',
#   'Ray LaMontagne',
#   'Robyn Hitchcock'),
#  ('Kings Of Convenience',
#   'Amos Lee',
#   'Laura Veirs',
#   'Lamb',
#   'Guy Capecelatro III',
#   'Iron & Wine',
#   'Elliott Smith',
#   'Dolorean',
#   'The Valery Trails'),
#  ('Boney M.',
#   'DJ PP',
#   'El Zorro',
#   'Mac Zimms',
#   'Olav Basoski',
#   'Daft Punk',
#   'dBerrie',
#   'Baggi Begovic',
#   'Bob Marley & The Wailers'),
#  ('Eiffel',
#   'Ramin Djawadi',
#   'Mogwai',
#   'Olafur Arnalds',
#   'At The Drive-In',
#   'Michael Kamen',
#   'Suzanne Ciani',
#   'Joey Scarbury',
#   'Sober'),
#  ('Slash',
#   'Young the Giant',
#   'Led Zeppelin',
#   'Alter Bridge',
#   'Of Monsters and Men',
#   'Roger Taylor',
#   'Three Days Grace',
#   'Soweto String Quartet',
#   'David Arnold'),
#  ('Sober', 'The Struts', 'Victor Wooten', 'L-Kan'),
#  ('James Galway',
#   'Mike Oldfield',
#   'This Mortal Coil',
#   'Tim Buckley',
#   'Billy Oskay',
#   'Barbara Higbie',
#   'Russel Walder'),
#  ('Hilario Camacho (F)',
#   'Luis Eduardo Aute',
#   'Max Richter',
#   'Ehren Starks',
#   'Seamus Egan',
#   'Harvey Danger',
#   'Austin Wintory',
#   'Arcade Fire',
#   'Camel'),
#  ('How To Destroy Angels', 'Luis Eduardo Aute', 'Zigmat', 'Extremoduro'),
#  ('Molotov',
#   'Moloko',
#   'The Police',
#   'Roger Waters',
#   'Hans Zimmer',
#   'Jethro Tull',
#   'Tracy Bonham',
#   'Scissor Sisters',
#   'Queen'),
#  ('Cobra Starship',
#   'Carly Rae Jepsen',
#   'Robyn',
#   'LMFAO',
#   'Martin Solveig',
#   'Flo Rida'),
#  ('Bill Withers',
#   'Aretha Franklin',
#   'William Bell',
#   'Grover Washington, Jr.',
#   'Bobby Caldwell',
#   'Teddy Pendergrass'),
#  ('Dada Life',
#   'Fatboy Slim',
#   'Daft Punk - Stardust',
#   'Dimmi',
#   'Klingande',
#   'Dillon Francis',
#   'John De Sohn',
#   'The Broken Flowers Project'),
#  ('Ice T',
#   'Sen Dog',
#   'Above The Law',
#   'DJ Quik',
#   'Coolio & 40 Thevz',
#   'The Egyptian Lover',
#   'Cypress Hill',
#   'Pac Div'),
#  ('Hot Water Music',
#   'Foxy Shazam',
#   'Lucero',
#   'Brian Fallon',
#   'Willie Nelson',
#   'Tom Gabel',
#   'U2'),
#  ('Lykke Li', 'The Tallest Man On Earth', 'Willy Mason', 'Johnny Flynn'),
#  ('Kraftwerk',
#   'The Preatures',
#   'Beck',
#   '!!!',
#   'tUnE-yArDs',
#   'Har Mar Superstar'),
#  ('Paco De Lucia',
#   'Andy McKee',
#   'Tommy Emmanuel',
#   'Don Ross',
#   'Al Di Meola',
#   'Antoine Dufour'),
#  ('Chico Buarque', 'Maria Bethania', 'Ana Belen', 'Toquinho'),
#  ('Hidden Orchestra',
#   'Ennui',
#   "Big Spider's Back",
#   'D/R/U/G/S',
#   'Sun Airway',
#   'Babes',
#   'Gotye'),
#  ('Justin Bieber',
#   'Jeremih & 50 Cent',
#   'Ester Dean Feat Lil Wayne & Chris Brown',
#   'Lupe Fiasco',
#   'Chris Brown Ft. Lil Wayne and Busta Rhymes',
#   'Tinie Tempah Ft. Taio Cruz',
#   'Fabolous'),
#  ('Bananarama',
#   'Elton John',
#   'Genesis',
#   'John Mellencamp',
#   'Rod Stewart',
#   'Christopher Cross',
#   'Phil Collins',
#   'The Doobie Brothers'),
#  ('Mark Wonder',
#   'Tarrus Riley',
#   'Popcaan',
#   'Jesse Royal',
#   'Morgan Heritage',
#   'Alborosie',
#   'Mykal Rose'),
#  ('Alabama',
#   'Bruce Springsteen',
#   'Toby Keith',
#   'John Mellencamp',
#   'Brooks & Dunn'),
#  ('Paul Keen',
#   'Andrew Hugill, Taina Niemala',
#   'Les Grenouilles',
#   'Adam Swayne',
#   'I Chaplais, P Keen, T Niemala, K Stretton, A Swayne, R Uttley',
#   'Richard Uttley',
#   'Karis Stretton',
#   'Isabel Chaplais'),
#  ('Tom Petty And The Heartbreakers',
#   'Loudon Wainwright III',
#   'Drake',
#   'Diana Ross',
#   'The War On Drugs',
#   'Ryan Adams',
#   'Earl Sweatshirt',
#   'Disclosure',
#   'Oneohtrix Point Never'),
#  ('Animalistics',
#   'Alfa',
#   'Maethelvin',
#   'Barretso',
#   'Aeroplane',
#   'Russ Chimes'),
#  ('DJ Antoine',
#   'Sido',
#   'Icona Pop',
#   'Guru Josh Project',
#   'LMFAO',
#   'Adele',
#   'Remady & Manu-L',
#   'Macklemore & Ryan Lewis',
#   'Snoop Dogg'),
#  ('Saliva',
#   'Ja Rule',
#   'Brian Tyler',
#   'Wiz Khalifa',
#   'DJ Shadow',
#   'Teriyaki Boyz',
#   '2 Chainz'),
#  ('Crystal Castles', 'Crystal Castles VS Health', 'Crim3s', 'Grimes'),
#  ('Moby', 'sleepmakeswaves', 'Manchester Orchestra', 'Radiohead'),
#  ('U96',
#   'Paul van Dyk',
#   'Dune',
#   'Technohead',
#   'Klubbheads',
#   'Dance 2 Trance',
#   'DJ Jean',
#   'Future Breeze'),
#  ('The Dead Weather', 'The White Stripes', 'Jack White', 'The Raconteurs'),
#  ('Jimmy Buffett',
#   'Frank Sinatra',
#   'Billy Joel',
#   'Tom Petty And The Heartbreakers',
#   'Queen',
#   'Cobra Starship',
#   'Panic! At The Disco',
#   'Bruce Springsteen'),
#  ('Lana Del Rey',
#   'Metronomy',
#   'Totally Enormous Extinct Dinosaurs',
#   'Hot Chip',
#   'The D',
#   'Moloko'),
#  ('3OH!3', 'All Time Low', '2NE1', 'Panic! At The Disco'),
#  ('RJD2',
#   'Caribou',
#   'Vivien Goldman',
#   'Dorothy Collins (vocal)',
#   'Pierre Henry'),
#  ('Trap Them',
#   'Suicidal Tendencies',
#   'Sabertooth Zombie',
#   'Heavy Heavy Low Low',
#   'Trash Talk',
#   'Ceremony',
#   'Ministry',
#   'The Chariot',
#   'Every Time I Die'),
#  ('The Mooney Suzuki',
#   'Pink Floyd',
#   'Jay Reatard',
#   'Muse',
#   'The Jim Jones Revue',
#   'Dropkick Murphys',
#   'Foxboro Hottubs',
#   'FIDLAR'),
#  ('Agoria Feat.Tricky',
#   'Martina Topley Bird',
#   'Tricky',
#   'Massive Attack',
#   'Nearly God',
#   'Terranova',
#   'Sunshine'),
#  ('Sleater-Kinney',
#   'Sufjan Stevens',
#   'Modest Mouse',
#   'Cloakroom',
#   'Tobias Jesso Jr.',
#   'Father John Misty'),
#  ('Alaska Y Dinarama', 'Alaska Y Los Pegamoides', 'Fangoria', 'Alaska'),
#  ('Hudson Taylor',
#   'Dry the River',
#   'Zhu',
#   'Pulled Apart By Horses',
#   'SBTRKT',
#   'FKA twigs',
#   'Perfume Genius'),
#  ('Carlos Ann',
#   'Loquillo',
#   'Nacho Vegas',
#   'Bunbury',
#   'Morti',
#   'Shuarma',
#   'Phil Manzanera'),
#  ('The Stone Roses',
#   'Coldplay',
#   'Jimmy Eat World',
#   'Jamiroquai',
#   'Lifehouse',
#   'Daft Punk',
#   'Little Boots'),
#  ('Man With No Name', 'PSY', 'Virus', 'Wham!'),
#  ('The Rainstick Orchestra',
#   'Midwest Product',
#   'Tycho',
#   'Apparat',
#   'Marc Hellner',
#   'Barbara Morgenstern',
#   'Orbital',
#   'Telefon Tel Aviv',
#   'Oliver Nelson'),
#  ('The Chainsmokers',
#   'Lily Allen',
#   'Jungle',
#   'Dvbbs',
#   'David Guetta',
#   'Dimitri Vegas',
#   'Tove Lo'),
#  ('KAYEF', 'LIONT', 'T-zon', 'Lil Rain'),
#  ('Bob Schneider',
#   'Stereophonics',
#   'Wolf Parade',
#   'Better Than Ezra',
#   'Third Eye Blind',
#   'Sam Sparro',
#   'Blonde Redhead',
#   'VAST'),
#  ('Stroke 9',
#   'Matt Wertz',
#   'Bleu',
#   'Emerson Hart',
#   'The Damnwells',
#   'Jeff Buckley',
#   'Madonna',
#   'Tenacious D'),
#  ('Queen',
#   'Fleetwood Mac',
#   'Maxwell',
#   'Beck',
#   'Robert Randolph & The Family Band',
#   'Charlie Hunter Quintet',
#   'Red Hot Chili Peppers',
#   'Rock Kills Kid'),
#  ('UB40',
#   'Burning Spear',
#   'Inner Circle',
#   'Ziggy Marley',
#   'Reggae Beat',
#   'Phyllis Dillon',
#   'Junior Murvin',
#   'Hopeton Lewis'),
#  ('Diana Ross',
#   'The Supremes',
#   'Diana Ross & The Supremes',
#   'Lionel Richie',
#   'Valerie Simpson'),
#  ('Panic! At The Disco',
#   'Panic! At The Disco with fun.',
#   'Dillon Francis',
#   'La Santa Cecilia'),
#  ('Enya', 'Blue Stone', 'Moby', 'Ryan Farish'),
#  ('Stevie Nicks',
#   'Fleetwood Mac',
#   'Stevie Nicks & Don Henley',
#   'Stevie Nicks w/ Tom Petty and the Heartbreakers',
#   'Kenny Loggins'),
#  ('The Rolling Stones',
#   'Small Faces',
#   'The Doors',
#   'The Kinks',
#   'The Who',
#   'Dave Davies',
#   'Ray Davies'),
#  ('OK Go', 'Led Zeppelin', 'Foo Fighters', 'Metallica', 'Rodrigo y Gabriela'),
#  ('Flume', 'Anna Lunoe', 'Atmosphere', 'WEKEED'),
#  ('tUnE-yArDs',
#   'Emeli Sande',
#   'Crookers',
#   'Ben Howard',
#   'The Roots',
#   'Harvard',
#   "Donae'o"),
#  ('Taking Back Sunday',
#   'Dashboard Confessional',
#   'Northstar',
#   "Jack's Mannequin",
#   'Red Hot Chili Peppers',
#   'Pearl Jam'),
#  ('Rhye', 'Bebel Gilberto', 'Sade', 'Norah Jones', 'John Legend'),
#  ('Britney Spears',
#   'Limp Bizkit',
#   'Gorillaz',
#   'The Chemical Brothers',
#   'Backstreet Boys',
#   'No Doubt',
#   'The Offspring',
#   'Marilyn Manson',
#   'New Radicals'),
#  ('Hyolin (Sistar)', 'Lyn', 'Baek Ji Young', 'G.E.M.'),
#  ('U2', 'Jason Mraz', 'Two Spot Gobi', 'Tristan Prettyman'),
#  ('Cocteau Twins', 'The Cramps', 'Porcelain Raft', 'The Slits'),
#  ('Django Django',
#   "Blackbeard's Tea Party",
#   'Sonata Arctica',
#   'The Fray',
#   'Metronomy',
#   'INXS',
#   'Christy Moore'),
#  ('Coldplay',
#   'Trixie Whitley',
#   'The xx',
#   'Muse',
#   'Novastar',
#   'Lana Del Rey',
#   'Snow Patrol',
#   'Amatorski',
#   'Nick Cave & The Bad Seeds'),
#  ('Natural Born Deejays', 'Dance 2 Trance', 'B.B.E.', 'Kadoc'),
#  ('Washed Out',
#   'Miike Snow',
#   'Santigold',
#   'The Black Keys',
#   'Jack White',
#   'Kanye West'),
#  ('Crazy P',
#   'Doctor Rockit',
#   'Etienne de Crecy',
#   'Mylo',
#   'Various Artists',
#   'David Byrne/X-Press 2'),
#  ('Satanic Surfers', 'Benito Kamelas', 'Disidencia', 'Non Servium'),
#  ('Tycho',
#   'Colbie Caillat',
#   'London Grammar',
#   'Jason Mraz',
#   'Air',
#   'Gerard Joling'),
#  ('Soilwork',
#   'In Flames',
#   'Machinae Supremacy',
#   'Scar Symmetry',
#   'Bullet For My Valentine'),
#  ('50 Cent',
#   'Ying Yang Twins',
#   'MC Hammer',
#   'RUN-DMC',
#   'Eminem',
#   'The Game',
#   'DMX',
#   'Pusha T',
#   'Ice Cube'),
#  ('Samuel Barber',
#   'Anam Cara, James Jordan (conductor)',
#   'Stephen C. Foster',
#   'George Frideric Handel',
#   "Choir of King's College, Cambridge",
#   'Netherlands Chamber Choir',
#   'Eliza Gilkyson',
#   'Herbert Howells',
#   'The Anonymous'),
#  ('Wild Ones',
#   'Field Mouse',
#   'Alvvays',
#   'Tancred',
#   'Special Explosion',
#   'Koji',
#   'Hop Along'),
#  ('Sander Van Doorn',
#   'Dada Life',
#   'Major Lazer',
#   'Baauer',
#   'Flosstradamus',
#   'Zedd',
#   'Jack U'),
#  ('The Roots', 'Michel Chion', 'Mary Lou Williams', 'Nina Simone'),
#  ('Ryan Star',
#   'The Handsome Family',
#   'TV On The Radio',
#   'Antony & The Johnsons',
#   'Hozier',
#   'Mikky Ekko'),
#  ('Duck Sauce', 'Parov Stelar', 'Ratatat', 'The xx'),
#  ('Meghan Trainor',
#   'John Legend',
#   'The Royal Concept',
#   'Lilly Wood and The Prick',
#   'Capital Cities',
#   'Daryl Hall & John Oates',
#   'Kasabian'),
#  ('Coldplay',
#   'Kings Of Leon',
#   'Band Of Skulls',
#   'The Black Keys',
#   'The Killers',
#   'Muse'),
#  ('Neshama Carlebach',
#   'Nesahama Carleback',
#   'Golem',
#   'Di Naye Kapelye',
#   'De Leon',
#   'Neginah Orchestra',
#   'David & The High Spirit'),
#  ('Ted Gardestad',
#   'Gyllene Tider',
#   'Lasse Berghagen',
#   'Tomas Ledin',
#   'Lill-Babs',
#   'Magnus Uggla',
#   'Bjorn Skifs'),
#  ('Rivero',
#   'Buxxi',
#   'Birdy Nam Nam',
#   'Daddy Yankee',
#   'Nicolas Mayorca',
#   'Henry Mendez',
#   'Jose De Rico',
#   'DMX'),
#  ('Glasvegas',
#   'Noah And The Whale',
#   'Markus Krunegard',
#   'Slowdive',
#   'The Perishers',
#   'Vera Vinter'),
#  ('Max Richter', 'Robin Wright', 'Kwoon', 'M|O|O|N'),
#  ('Unwritten Law', 'Christopher Cross', 'Nicki Minaj', 'Saosin'),
#  ('Cole Porter',
#   'Chet Baker',
#   'Richard Rodgers',
#   'Johnny Green',
#   'JOHNNY BURKE',
#   'Miles Davis',
#   'Aaron Neville',
#   'Hoagy Carmichael'),
#  ('Austin Mahone',
#   'Katy Perry',
#   'Meghan Trainor',
#   'The Weeknd',
#   'Kelly Clarkson',
#   'Shawn Mendes'),
#  ('Tank', 'J. Holiday', 'The-Dream', 'Trey Songz', 'Miguel'),
#  ('Lorde',
#   'Quadron',
#   'Justin Timberlake',
#   'Blood Orange',
#   'CHVRCHES',
#   'The Internet',
#   'Frank Ocean',
#   'M'),
#  ('Natiruts', 'The Unlimiters', 'Major Lazer', 'Reggae Revolution'),
#  ('El Guincho', 'Bombay Bicycle Club', 'Kevin Roldan', 'Major Lazer'),
#  ('60 Tigres',
#   'The Guadaloops',
#   'Pipe Llorens',
#   'Yogui',
#   'Technicolor Fabrics',
#   'Zaque',
#   'Beat Buffet',
#   '424',
#   'Tino el Pinguino'),
#  ('Alvaro Diaz',
#   'Action Bronson',
#   'Kanye West',
#   'Nosaj Thing',
#   'Kendrick Lamar',
#   'Earl Sweatshirt',
#   'A$AP Rocky',
#   'iSHi',
#   'Kevin Roldan'),
#  ('Sky Ferreira',
#   'Wild Belle',
#   'Solange',
#   'Nicole Scherzinger',
#   'Classixx',
#   'Lorde'),
#  ('Joe Henderson',
#   'Stan Getz',
#   'Miguel Matamoros Matamoros',
#   'Luiz Bonfa',
#   'Antonio Carlos Jobim',
#   'Horace Silver',
#   'Sonny Rollins',
#   'Oscar Aleman',
#   'Zequinha De Abreu'),
#  ('Meck', 'deadmau5', 'Mr Oizo', 'Dance DJ & Company', 'Dash Berlin'),
#  ('Attack Attack!',
#   'Dream On Dreamer',
#   'Sleeping With Sirens',
#   'Aaron Fiocca',
#   'The Ghost Inside',
#   'Chunk! No, Captain Chunk!'),
#  ('Mass Hysteria',
#   'Les Garcons Bouchers',
#   'Les Sales Majestes',
#   'Berurier Noir',
#   'Les Wampas',
#   'Dropkick Murphys',
#   'Gogol Premier',
#   'Iggy Pop',
#   'Banane Metalik'),
#  ('Tyler, The Creator',
#   'Sufjan Stevens',
#   'Sugar',
#   'Chastity Belt',
#   'Dinosaur Jr.',
#   'Drake',
#   'Krill',
#   'Empty Pools',
#   'Laura Marling'),
#  ('Chelsea Grin', 'Sylar', 'The Word Alive', 'Like Moths To Flames'),
#  ('NONONO', 'Rusted Root', 'Walk the Moon', 'Tegan And Sara'),
#  ('Erasure',
#   'Built To Spill',
#   'New Order',
#   'Joy Division',
#   'Nine Inch Nails',
#   'Depeche Mode',
#   'The Cure'),
#  ('Within Temptation',
#   'Metallica',
#   'Dream Theater',
#   'Kamelot',
#   'Vanden Plas',
#   'Avantasia',
#   'Helloween',
#   'Epica'),
#  ('Junip',
#   'Family of the Year',
#   'The Heavy',
#   'Rogue Wave',
#   'Jose Gonzalez',
#   'The Mountain Goats',
#   'alt-J',
#   'Crosby, Stills, Nash & Young'),
#  ('Natiruts',
#   'Gabriel O Pensador',
#   'Marcelo D2',
#   'Seu Jorge',
#   'Onze:20',
#   'Chimarruts',
#   'Forfun'),
#  ('Creedence Clearwater Revival',
#   'Derek & The Dominos',
#   'Jimmy Reed',
#   'Motown Masters',
#   'Brian Setzer',
#   'Chuck Berry',
#   'Eddie Cochran'),
#  ('Motionless In White',
#   'Asking Alexandria',
#   'Chimaira',
#   'Whitechapel',
#   'I Killed The Prom Queen'),
#  ('Dixie Chicks',
#   'Drive By Truckers',
#   'Wilco',
#   'The Beatles',
#   'The Avett Brothers',
#   'She & Him',
#   'Justin Townes Earle'),
#  ('Bill Withers',
#   'Bread',
#   'Cal Smith',
#   'The Mamas & The Papas',
#   'The Kendalls',
#   'Simon & Garfunkel',
#   'Waylon Jennings',
#   'James Taylor',
#   'Paul Simon & Art Garfunklel -'),
#  ('Cults', 'The National', 'Pearl Jam', 'Andrew W.K.'),
#  ('Sixto Rodriguez',
#   'Daft Punk',
#   'The Dandy Warhols',
#   'Woodkid',
#   'Queens Of The Stone Age',
#   'Beck',
#   'Vampire Weekend',
#   'Lana Del Rey',
#   'Sin Fang'),
#  ('Mike Doughty',
#   'Lykke Li',
#   'Walk the Moon',
#   'Wilco',
#   'Pearl Jam',
#   'Darwin Deez',
#   'Birdy',
#   'Vampire Weekend',
#   'James Blunt'),
#  ('Metronomy (Remix: Breakbot)',
#   'Nudge',
#   'Bibio',
#   "Ariel Pink's Haunted Graffiti",
#   'Maps'),
#  ('Martha Reeves & The Vandellas',
#   'Bobby Womack',
#   'Wendy Rene',
#   'The Temptations',
#   'William Bell',
#   'The Brothers Grimm',
#   'The Contours',
#   'Dee Edwards'),
#  ('John Coltrane',
#   'Charlie Parker',
#   'Morphine',
#   'Charlie Parker and Dizzy Gilespe',
#   'Miles Davis',
#   'Rollins Band',
#   'Lester Young and Charlie Parker',
#   'Duke Ellington',
#   'Miles Davis and John Coltrane'),
#  ('August Burns Red', 'The Color Morale', 'The Overseer', 'Of Mice & Men'),
#  ('Nina Simone',
#   'Solomon Burke',
#   'Bill Withers',
#   'Marvin Gaye',
#   'Wilson Pickett',
#   'The Temptations',
#   'Al Green',
#   'Aretha Franklin'),
#  ('Crowder',
#   'Vineyard Music',
#   'Robin Mark',
#   'Lincoln Brewster',
#   'Vineyard Worship'),
#  ('King Krule',
#   'Arthur Russell',
#   'Kate Bush',
#   'Beyonce',
#   'Karen Dalton',
#   'Dirty Projectors',
#   'Camille',
#   'Nico'),
#  ('Sean Kingston',
#   'Ne-Yo',
#   'Jeremih',
#   "Destiny's Child",
#   'Brick & Lace',
#   'Ciara',
#   'Beyonce'),
#  ('The Cat Empire', 'C2C', 'Various Artists', 'Just Jack', 'Mark Ronson'),
#  ('Colour Haze',
#   'Wintersleep',
#   'Elder',
#   'MeWithoutYou',
#   'Electric Wizard',
#   'Quest For Fire',
#   'Led Zeppelin',
#   'The Allman Brothers Band'),
#  ('Big Ups', 'Shearwater', 'You Blew It!', 'Mogwai'),
#  ('Donovan Wolfington',
#   'Broadway Calls',
#   'Mock Orange',
#   'WALLA',
#   'Wintersleep',
#   'Gemini Club',
#   'The Big Pink',
#   'The Foxglove Hunt',
#   'This Many Boyfriends'),
#  ('Nena',
#   'Toto',
#   'Foo Fighters',
#   'Krispy Kreme',
#   'Men At Work',
#   'Weezer',
#   'The Smashing Pumpkins'),
#  ('The Head And The Heart',
#   'Motion City Soundtrack',
#   'The Civil Wars',
#   'Elliott Smith',
#   'Heartless Bastards',
#   'Death Cab for Cutie',
#   'Grizzly Bear'),
#  ('Cold War Kids',
#   'Rilo Kiley',
#   'Monsters Of Folk',
#   'Brendan Benson',
#   'Elliott Smith'),
#  ('Trinidad James', 'Alicia Keys', 'Lil Wayne', 'Lisa Miskovsky'),
#  ('Stars',
#   'Millencolin',
#   'The Weakerthans',
#   'The Good Life',
#   'The Postal Service',
#   'Dr. Dog'),
#  ('David Bowie', 'Iggy Pop', 'a-ha', ' (Crosses)'),
#  ('The Stooges',
#   'Ramones',
#   'The Velvet Underground',
#   'T. Rex',
#   'Television',
#   'David Bowie',
#   'Pink Floyd'),
#  ('Soda Stereo',
#   'Pescado Rabioso',
#   'Andres Calamaro',
#   'Vox Dei',
#   'Los Fabulosos Cadillacs',
#   'Charly Garcia',
#   'Los Abuelos De La Nada',
#   'Sumo'),
#  ('Pitbull', 'Alexis Jordan', 'Little Boots', 'Tinchy Stryder'),
#  ('Flight Facilities',
#   'Prefuse 73',
#   'The xx',
#   'Breakbot Feat. Irfane',
#   'The Heavy',
#   'Holy Ghost!',
#   'Penguin Prison',
#   'Gramatik',
#   'Muse'),
#  ('Rick Ross',
#   'JANET JACKSON',
#   'Trey Songz',
#   'Ryan Leslie',
#   'Jay-Z Feat. Pharrell',
#   'Dirty Money',
#   'Kanye West',
#   'Tank'),
#  ('The Head And The Heart',
#   'Paul McCartney',
#   'The Avett Brothers',
#   'Gavin DeGraw',
#   'Pearl Jam'),
#  ('Billy Idol', 'Fever Marlene', 'Y LUV', 'The Royal Concept', 'Paul Simon'),
#  ('Texas In July',
#   'Miss May I',
#   'We Came As Romans',
#   'Close to Home',
#   'Of Mice & Men'),
#  ('Heartless Bastards',
#   'Churchill',
#   'Dragonette',
#   'The Front Bottoms',
#   'Dum Dum Girls'),
#  ('Cur De Pirate',
#   'Darren Korb',
#   'Video Games Live',
#   'Nobuo Uematsu',
#   'Gustavo Santaolalla',
#   'Syd Matters'),
#  ('Drake', 'Katy Perry', 'Owl City', 'Prince'),
#  ('Mayer Hawthorne',
#   'Father John Misty',
#   'Dawes',
#   'Allen Stone',
#   'The Lennings'),
#  ('Misery Signals',
#   'After The Burial',
#   'Veil Of Maya',
#   'Within The Ruins',
#   'Your Memorial'),
#  ('Cheers Elephant',
#   'Rilo Kiley',
#   'Further Seems Forever',
#   'Taylor Swift',
#   'The Civil Wars'),
#  ('Labrinth',
#   'Emeli Sande',
#   'Kodaline',
#   'Florence + The Machine',
#   'Drake',
#   'Ben Howard'),
#  ('Alien Ant Farm',
#   'Ash',
#   'Queens Of The Stone Age',
#   'The Ataris',
#   'Foo Fighters'),
#  ('Jenny Lewis',
#   'The Wonder Years',
#   'Bright Eyes',
#   'The Get Up Kids',
#   'Sun Airway'),
#  ('Jimmy Y Angel', 'Pescozada', 'Crooked Stilo', 'Roberto Salamanca'),
#  ('AFI',
#   'Green Day',
#   'Evanescence',
#   'Seether',
#   'Patti Smith',
#   'Flyleaf',
#   'The Beatles',
#   'Within Temptation',
#   'Breaking Benjamin'),
#  ('Ewert and the Two Dragons',
#   'Angus & Julia Stone',
#   'Dan Croll',
#   'Nils Frahm',
#   'Fiona Apple',
#   'MS MR',
#   'Cur De Pirate',
#   'CHVRCHES',
#   'Marble Sounds'),
#  ('Pearls before Swine Experience',
#   'Lucinda Williams',
#   'The Zombies',
#   'Fairport Convention',
#   'The Incredible String Band',
#   'Wilco',
#   'Marion Williams',
#   'The Walkabouts',
#   'Pearls Before Swine'),
#  ('Louis Prima',
#   'The Louvin Brothers',
#   'Keely Smith',
#   'Elvis Presley',
#   'Frank Sinatra'),
#  ('Slipknot',
#   'MGMT',
#   'Elbow',
#   'Q-Tip',
#   'Fleet Foxes',
#   'TV On The Radio',
#   'Portishead'),
#  ('Wild Beasts', 'Animal Collective', 'The xx', 'Yeah Yeah Yeahs'),
#  ('Beach House',
#   'Janelle Monae',
#   'Kanye West',
#   'Deerhunter',
#   'The Black Keys',
#   'John Grant'),
#  ('Hot Chip', 'Kendrick Lamar', 'Frank Ocean', 'Jack White', 'Django Django'),
#  ('George Bruns', 'Bill Lee', 'Mel Levin', 'Lucille Bliss'),
#  ('Eurythmics',
#   'Enigma',
#   'Friends',
#   'Ready For The World',
#   'Chairlift',
#   'Prince'),
#  ('Arcade Fire',
#   'LCD Soundsystem',
#   'The xx',
#   'The National',
#   'The Flaming Lips',
#   'Devendra Banhart',
#   'Babasonicos',
#   'Gorillaz'),
#  ('10cc', 'Wax', 'Godley & Creme', 'Hotlegs'),
#  ('Hole', 'Grandaddy', 'Honey Is Cool', 'The Hives', 'Hakan Hellstrom'),
#  ('Noir & Haze',
#   'Trentemller',
#   'Connan Mockasin',
#   'Zahed Sultan',
#   'Chromatics',
#   'Gil Scott-Heron',
#   'M83',
#   'Koudlam'),
#  ('Regina Spektor',
#   'The Weepies',
#   'Ingrid Michaelson',
#   'Adele',
#   'Sara Bareilles'),
#  ('Bon Iver',
#   'Roo Panes',
#   'James Blake',
#   'The Tallest Man On Earth',
#   'Phosphorescent',
#   'Elbow'),
#  ('Ice Nine Kills', 'Adestria', 'Attila', 'Issues', 'Make Me Famous'),
#  ('Maria Taylor',
#   'The Good Life',
#   'Kate Nash',
#   'Ted Leo and the Pharmacists',
#   'Motion City Soundtrack',
#   'The Get Up Kids'),
#  ('The Lawrence Arms', 'Tegan And Sara', 'Stars', 'Ben Howard', 'A.A. Bondy'),
#  ('Dinosaur Jr.', 'Ra Ra Riot', 'Kate Nash', 'Frightened Rabbit', 'Metric'),
#  ('Okkervil River',
#   'The Gaslight Anthem',
#   'Jack White',
#   'The Mountain Goats',
#   'Andrew Bird'),
#  ('Clint Mansell & Sam Hulick',
#   'The xx',
#   'Clint Mansell',
#   'Konami Kukeiha Club'),
#  ('Rosana', 'Nino Bravo', 'Tamara', 'Mecano', 'Jeanette', 'Nena Daconte'),
#  ('Sara Bareilles',
#   'Imagine Dragons',
#   'Jason Mraz',
#   'Katy Perry',
#   'Lily Allen',
#   'Glee Cast',
#   'Julia Sheer',
#   'Street Corner Symphony'),
#  ('112', 'Slim', "Lil' Zane", 'Mobb Deep'),
#  ('Panda Bear',
#   'Angus & Julia Stone',
#   'Lana Del Rey',
#   'Justin Townes Earle',
#   'Mark Ronson',
#   'Matt and Kim',
#   'MisterWives'),
#  ('Incubus',
#   'Kid Cudi',
#   'Flobots',
#   'The Lumineers',
#   'Aloe Blacc',
#   'We Were Promised Jetpacks',
#   'Sublime'),
#  ('Brian Eno', 'Mount Eerie', 'Sonic Youth', 'Ornette Coleman'),
#  ('Timbaland', 'Kanye West', 'Tyga', 'DJ Khaled'),
#  ('Celtas Cortos',
#   'DePedro',
#   'Facto Delafe y las flores azules',
#   'La Habitacion Roja'),
#  ('MellowHype',
#   'Tyler, The Creator',
#   'Jet Age of Tomorrow',
#   'Mike G',
#   'Domo Genesis',
#   'The Internet'),
#  ('Theophilus London', 'Flo Rida', 'Nicki Minaj', 'I LOVE MAKONNEN'),
#  ('Elliott Smith',
#   'Alkaline Trio',
#   'Rilo Kiley',
#   'City and Colour',
#   'Death Cab for Cutie'),
#  ('TLC', 'Shai', 'The Killers', 'Bruno Mars'),
#  ('Boy & Bear',
#   'Angus & Julia Stone',
#   'James Bay',
#   'Born Ruffians',
#   'MisterWives',
#   'Matt Corby',
#   'Phosphorescent',
#   'Dry the River'),
#  ('Kutless', 'Phil Wickham', 'Discovery band', 'Robbie Seay Band', 'Fee'),
#  ('The Menzingers',
#   'Chuck Ragan',
#   'The Helio Sequence',
#   'Fiona Apple',
#   "Margot & The Nuclear So And So's"),
#  ('La Roux',
#   'Ladytron',
#   'Eminem',
#   'Hot Chip',
#   'Debilos',
#   'Daft Punk',
#   'Yeah Yeah Yeahs'),
#  ('Sabaton',
#   'Raised Fist',
#   'Deathember',
#   'In Flames',
#   'Nero',
#   'Amaranthe',
#   'BABYMETAL',
#   'The Unguided',
#   'Pendulum'),
#  ('Iron Maiden',
#   'Stone Gods',
#   'The Hives',
#   'LOK',
#   'Van Halen',
#   'Bruce Dickinson',
#   'Dokken',
#   'Billy Idol'),
#  ('A.R. Rahman',
#   'Sigur Ros',
#   'Dido',
#   'Esther Phillips',
#   'Bill Withers',
#   'Free Blood',
#   'Vladimir Ashkenazy',
#   'Plastic Bertrand'),
#  ('Doomtree',
#   'PHOX',
#   'Natalie Prass',
#   'Death Cab for Cutie',
#   'The Lone Bellow',
#   'Milo Greene',
#   'AWOLNATION',
#   'SOAK'),
#  ('Hilarious Hit Makers', 'Sparklehorse', 'Mojave 3', 'Cool Calm Pete'),
#  ('Passion',
#   'Jesus Culture',
#   'Hillsong Worship',
#   '12Stone Worship',
#   'Meredith Andrews',
#   'Hillsong United'),
#  ('12th Planet, Skrillex, & Kill the Noise feat. GMCFOSHO',
#   '12th Planet & Antiserum',
#   '12th Planet',
#   '12th Planet & SPL',
#   '12th Planet & Flinch'),
#  ('Deltron 3030', 'Blueprint', 'Soul Position', 'Del The Funky Homosapien'),
#  ('Gravediggaz',
#   'Spice 1',
#   'The Notorious B.I.G.',
#   'Nas',
#   'Luniz featuring Michael Marshall',
#   'Raekwon',
#   'Method Man'),
#  ('Brother Ali', 'Cypress Hill', 'Jedi Mind Tricks', 'Apathy'),
#  ('Paul McCartney',
#   'Eric Clapton',
#   'Creedence Clearwater Revival',
#   'The Blues Brothers',
#   'Johnny Winter',
#   'Ronnie Wood',
#   'Frankie and the Real Rockers',
#   'Tony Sheridan & The Beatles'),
#  ('will.i.am',
#   'Justin Bieber',
#   'Example',
#   'Sebastian Ingrosso',
#   'Aly & Fila',
#   'Tiesto',
#   'Various Artists'),
#  ('The Connells', 'HOFFMAESTRO', 'Rolf Wikstrom', 'Velvet Revolver'),
#  ('Le Tigre', 'Ladytron', 'The Knife', 'Madness'),
#  ('Kari Jobe', 'Jason Gray', 'Downhere', 'Matthew West'),
#  ('Phoenix', 'Kings Of Leon', 'Tame Impala', 'Django Django', 'alt-J'),
#  ('Nirvana',
#   'Miss Universum',
#   'Modest Mouse',
#   'Moby',
#   'Missy Elliott',
#   'The Make-Up',
#   'Luscious Jackson',
#   'Massive Attack',
#   'Miss Kittin And The Hacker'),
#  ('Kodaline',
#   'JMR',
#   'Port St. Willow',
#   'Mutual Benefit',
#   'Bon Iver',
#   'Lanterns on the Lake',
#   'Emma Louise',
#   'Wye Oak',
#   'Vancouver Sleep Clinic'),
#  ('Chet Faker', 'Kylie Minogue', 'Lykke Li', 'Iron & Wine'),
#  ('Hillsong Worship', 'Jeremy Camp', 'Elevation Worship', 'Sidewalk Prophets'),
#  ('Matt Redman',
#   'Hillsong Worship',
#   'Elevation Worship',
#   'The Jason Lovins Band'),
#  ('Musiq', 'The REAZUN', 'The Game', '14 KT'),
#  ('Peder Mannerfelt',
#   'South London Ordnance',
#   'Cub',
#   'YA r',
#   'Positive Centre',
#   'Low Jack',
#   'Shifted',
#   'Streetwalker',
#   'Tolouse Low Trax'),
#  ('Throwing Shade', 'Evan Baggs', 'Nadus', 'Throwing Shade feat. Emily Bee'),
#  ('Beck',
#   'Animal Collective',
#   'The Beatles',
#   'Psychic Stunts',
#   'Radiohead',
#   'Black Flag',
#   'Royksopp'),
#  ('CAZZETTE',
#   'BRNS',
#   'James Bay',
#   'Conrad Sewell',
#   'Ry / Frank Wiedemann',
#   'The Vaccines',
#   'Dillon Francis feat. Totally Enormous Extinct Dinosaurs'),
#  ('Parkway Drive',
#   'This Or The Apocalypse',
#   'Destroy The Runner',
#   'Phinehas',
#   'Manafest',
#   'Underoath',
#   'My Heart to Fear'),
#  ('Pharrell',
#   'DJ Danger Mouse',
#   'Tears For Fears',
#   'Vas Defrans',
#   'Clockwork Orange',
#   'Catfish and the Bottlemen',
#   'You, Me, And Everyone We Know'),
#  ('Sean Hayes',
#   '16 Horsepower',
#   'Johnny Flynn',
#   'Danny Schmidt',
#   "The Wailin' Jennys"),
#  ("Mady Mesple/Danielle Millet/Orchestre du Theatre National de I'Opera-Comique/Alain Lombard",
#   'George Frideric Handel',
#   'Giacomo Puccini',
#   'Placido Domingo',
#   'Sara Mingardo'),
#  ('Pietro Mascagni',
#   'London Philharmonic Orchestra',
#   'Richard Wagner',
#   'Orchestra Del Teatro Alla Scala, Milano'),
#  ('Tulio Serafin', 'George Frideric Handel', 'Maria Callas', 'Yvonne Kenny'),
#  ('Zeze Di Camargo & Luciano',
#   'Luan Santana',
#   'Ivete Sangalo',
#   'Rastape',
#   'Bruno & Marrone',
#   'Falamansa'),
#  ('Haim', 'Stars', 'A Tribe Called Red', 'Charli XCX'),
#  ('MSTRKRFT',
#   'Digitalism',
#   'Foo Fighters',
#   "The O'Jays",
#   'Flo Rida',
#   'Justice',
#   'Vitalic',
#   'Rihanna'),
#  ('Tina Faigen',
#   'Elisabeth Leonskaja',
#   'Johann Sebastian Bach',
#   'Ludwig van Beethoven',
#   'Wolfgang Amadeus Mozart',
#   'Stuttgart Piano Trio',
#   'Franz Schubert',
#   'Ralph Kirshbaum'),
#  ('Pixies', 'Peaches', 'Pet Shop Boys', 'Pavement'),
#  ('Calvin Harris',
#   'Calvin Harris Feat. Kelis',
#   'Dizzee Rascal',
#   'Calvin Harris and Nicky Romero'),
#  ('PJ Harvey', 'Placebo', 'Public Enemy', 'Portishead', 'The Plan', 'Pixies'),
#  ('Hatiras, MC Flipside', 'Pallers', 'Air', 'DJ Mehdi', 'Hatiras', 'Dirtcaps'),
#  ('18+',
#   'Antonio Sanchez',
#   'Violeta Urmana / Wiener Philharmoniker / Pierre Boulez',
#   'Beaux Arts Trio',
#   'John Adams',
#   'Stuttgart Radio Symphony Orchestra',
#   'Stefano Seghedoni',
#   'Polish National Radio Symphony Orchestra'),
#  ('Love As Laughter',
#   'Ugly Casanova',
#   'James Mercer',
#   'Mason Jennings',
#   'Jack Johnson'),
#  ('Broder Daniel',
#   'Interpol',
#   'James Brown',
#   'Jakob Hellman',
#   'The Chemical Brothers'),
#  ('Daft Punk',
#   'Bloc Party',
#   'Beck',
#   'Sebastian',
#   'The Field',
#   'The Virgins',
#   'SebastiAn'),
#  ('Frank Sinatra',
#   'Gene Autry',
#   'Fred Astaire',
#   '1930s and 1940s Music',
#   'Glenn Miller',
#   'Bing Crosby'),
#  ('Blossom Dearie',
#   'Ella Fitzgerald',
#   "Johnny Burnette & The Rock 'N' Roll Trio",
#   'Duke Ellington',
#   'Elvis Presley',
#   'Frank Sinatra',
#   'Sonny Rollins'),
#  ('David Bowie', 'Rush', 'Boston', 'Styx'),
#  ('Journey',
#   'Bryan Adams',
#   'Lionel Richie',
#   'Rick Astley',
#   'Prince',
#   'a-ha',
#   'The Buggles',
#   'Wham!'),
#  ('James Blunt',
#   'Jay Sean',
#   'Ini Kamoze',
#   'Timbaland',
#   'Private',
#   'Emerson, Lake & Palmer'),
#  ('Toto',
#   'Talking Heads',
#   'Wang Chung',
#   'Culture Club',
#   'The Human League',
#   'Duran Duran',
#   'a-ha'),
#  ('Stray Cats',
#   'Restless',
#   'Guana Batz',
#   'The Polecats',
#   'Deuces Wild',
#   'The Ringlets Trio',
#   'The Sureshots'),
#  ('Echo And The Bunnymen', 'The Cure', 'Brian Eno', 'Eyeless In Gaza'),
#  ('Anthrax', 'Sade', 'Suzanne Vega', 'Lolita Pop'),
#  ('Todd Terry Project', 'Raze', 'Jungle Brothers', 'The Housemaster Boyz'),
#  ('Paul Van Dyk',
#   'One Phat Diva',
#   'Layo & Bushwacka',
#   'Faithless',
#   'Rui Da Silva Feat. Cassandra'),
#  ('Grandaddy',
#   'Daft Punk',
#   'The Verve',
#   'blink-182',
#   'Will Smith',
#   'Third Eye Blind',
#   'Marcy Playground',
#   'Chumbawamba',
#   'Pixies'),
#  ('Maria Kalaniemi',
#   'Salif Keita',
#   'Sheila Chandra',
#   'Cherish The Ladies',
#   'Dick Gaughan',
#   'Spiro',
#   'Lisa Lynne'),
#  ('Art Of Noise',
#   'Connie Dover',
#   'Afro Celt Sound System',
#   '3rd Force',
#   'Hans Zimmer'),
#  ('Camerata Meiga',
#   'Xuacu Amieva',
#   'Catatonia',
#   'Vusi Mahlasela',
#   'Tejedor',
#   'Kandia Kouyate',
#   'Afro Celt Sound System'),
#  ('Eleftheria Arvanitaki',
#   'Art Of Noise',
#   'Juan Jose Mosalini',
#   'Kathryn Tickell'),
#  ('Angelspit',
#   'Combichrist',
#   'KMFDM',
#   'Nine Inch Nails',
#   'Suicide Commando',
#   'Velvet Acid Christ',
#   'Front Line Assembly',
#   ':Wumpscut:'),
#  ('Michael Jackson',
#   'Jordi Savall',
#   'Berliner Philharmoniker',
#   'Nat King Cole',
#   'John Coltrane',
#   'Antonio Vivaldi',
#   'Leos Janacek',
#   'Johann Sebastian Bach',
#   'Orchestre Lamoureux'),
#  ('Malika Ayane', 'Echosmith', 'Cobra Starship', 'Nina Zilli', 'Mark Ronson'),
#  ('Koan Sound',
#   'Kaskade',
#   'Late Night Alumni',
#   'The Strokes',
#   'Deerhoof',
#   'The Chap',
#   'My Bloody Valentine'),
#  ('Karmin', 'Medina', 'Maria Mena', 'Avicii', 'Loreen', 'David Guetta'),
#  ('A Tribe Called Quest',
#   'Souls Of Mischief',
#   'The Pharcyde',
#   'Pete Rock & C.L. Smooth',
#   'Smif-N-Wessun'),
#  ('Manic Street Preachers',
#   'Overtone',
#   'Robyn',
#   'Brandon Flowers',
#   'Shakira',
#   'Ferry Corsten',
#   'The Divine Comedy',
#   'Lissie',
#   'Lady Gaga'),
#  ('JasWho?',
#   'Gangrene (The Alchemist & Oh No);DJ Romes',
#   'Johnny Flynn',
#   'Young The Giant',
#   'Poncho',
#   'Julia Stone',
#   'Warpaint'),
#  ('M.I.A.',
#   'Capital Cities',
#   '2 Chainz',
#   'Mariah Carey',
#   'Solange',
#   'Kendrick Lamar'),
#  ('The Mountain Goats',
#   'Lemuria',
#   'The Unlovables',
#   'Bad Religion',
#   'The Steinways',
#   'Rory Breaker',
#   'Tigers Jaw',
#   'Reggie and the full effect!',
#   'Damone'),
#  ('The xx',
#   'Iggy Azalea',
#   'Lana Del Rey',
#   'Kanye West',
#   'Lorde',
#   'Melanie Martinez',
#   'Crystal Castles',
#   'Mickey Avalon',
#   'Marina and The Diamonds'),
#  ('Duran Duran',
#   'OneRepublic',
#   'Christina Aguilera',
#   'Journey',
#   'Rihanna',
#   'Clutch',
#   'The Offspring',
#   'The Cardigans'),
#  ('Moderat', 'M|O|O|N', 'Darkside', 'Jacques Greene', 'Ital Tek'),
#  ('Okkervil River',
#   'Amos Lee',
#   'The Avett Brothers',
#   'Mumford & Sons',
#   'Bon Iver',
#   'Norah Jones'),
#  ('Tegan And Sara',
#   'Beastie Boys',
#   'St. Vincent',
#   'Santigold',
#   'Lissie',
#   'The Ting Tings'),
#  ('MF Doom [MM....Food]',
#   'Talib Kweli and Hi-Tek- Just Begun feat. Jay Electronica, J Cole',
#   'Mac Miller',
#   'Phish',
#   'D Double E'),
#  ('Orbital',
#   'Ke$ha',
#   'The Wanted',
#   'Kanye West',
#   'Adele',
#   'The Chemical Brothers',
#   'Calvin Harris',
#   'Rihanna'),
#  ('Phantogram',
#   'Banks',
#   'Haim',
#   'Townes Van Zandt',
#   'Miami Horror',
#   'Jimi Hendrix',
#   'Angel Olsen'),
#  ('The Jealous Sound',
#   'La Dispute',
#   'The Menzingers',
#   'Balance And Composure',
#   'Hot Water Music'),
#  ('Craig David',
#   'Adele',
#   'Foster The People',
#   'Broken Bells',
#   'Bruno Mars',
#   'Maroon 5'),
#  ('Laura Pausini',
#   'Charles Aznavour - Laura Pausini',
#   'Ray Charles',
#   'Miguel Bose',
#   'Michael Buble',
#   'Charles Aznavour'),
#  ('Mormon Tabernacle Choir',
#   'Eugene Ormandy',
#   'Richard P. Condie',
#   'Eugene Ormandy, The Philadelphia Orchestra, Mormon Tabernacle Choir',
#   'Philadelphia Orchestra'),
#  ('Ramones', 'The Vaccines', 'Rush', 'Soundgarden'),
#  ('Hot Chip',
#   'MGMT',
#   'Sophie Rimheden',
#   'Holy Fuck',
#   'Yeah Yeah Yeahs',
#   'Kraftwerk'),
#  ('JELO',
#   'The Tunics',
#   'Glasvegas',
#   'MGMT',
#   'We Are Wolves',
#   'Benny Benassi',
#   'Anna Ternheim',
#   'The Black Keys'),
#  ('Requiebros', 'Albahaca', 'Amigos De Gines', 'El Pali'),
#  ('Bedouin Soundclash',
#   'Hot Water Music',
#   'lostprophets',
#   'Train',
#   'The Goo Goo Dolls',
#   'City and Colour',
#   'Sublime',
#   'Tegan And Sara'),
#  ('Gwen Stefani',
#   'Selena Gomez & The Scene',
#   'Hilary Duff',
#   'Avril Lavigne',
#   'Lindsay Lohan',
#   'Ashley Tisdale',
#   'Ashlee Simpson'),
#  ('Arctic Monkeys',
#   'Bright Eyes',
#   'Sigur Ros',
#   'Muse',
#   'At The Drive-In',
#   'Bloc Party',
#   'The Killers',
#   'Kvelertak',
#   'The Mars Volta'),
#  ('Bavarian Radio Symphony Orchestra',
#   'Berliner Philharmoniker',
#   'Sudwestfunk Symphony Orchestra',
#   'Leningrad Philharmonic Orchestra',
#   'Helmut Franz'),
#  ('Paul Westerberg', 'The National', 'Air', 'Lemon Jelly'),
#  ('Avril Lavigne',
#   'Nelly',
#   'P!nk',
#   'Nickelback',
#   'Linkin Park',
#   'Eminem',
#   'Anastacia',
#   'Chambao',
#   'Shakira'),
#  ('The National',
#   'Death Cab for Cutie',
#   'Sufjan Stevens',
#   'The Postal Service',
#   'Jack Johnson',
#   'Grandaddy',
#   'Explosions In The Sky'),
#  ('Bebe',
#   'Fito Paez',
#   'Los Manolos',
#   'Dixie Chicks',
#   'Queen',
#   'Pastora',
#   'Joaquin Sabina y Fito Paez',
#   'Fermin Muguruza',
#   'Shrek'),
#  ('Lambchop',
#   'Brightblack Morning Light',
#   'Liars',
#   'Neil Young',
#   'Calexico',
#   'Sigur Ros',
#   'Howe Gelb',
#   'Bruce Springsteen',
#   'The Flaming Lips'),
#  ('Christina Aguilera',
#   'Gnarls Barkley',
#   'Dixie Chicks',
#   'Rihanna',
#   'Lily Allen',
#   'Sean Paul',
#   'My Chemical Romance'),
#  ('From First To Last',
#   'Billy Talent',
#   'Taking Back Sunday',
#   'The Blackout',
#   'Satyricon',
#   'Bring Me The Horizon',
#   'Bison',
#   '+44'),
#  ('Sting',
#   'Brian Keane',
#   'John Rutter',
#   'Peter Kater',
#   'Martyn Bennett',
#   'Planxty',
#   'Edin Karamazov'),
#  ('The Good, The Bad & The Queen',
#   'LCD Soundsystem',
#   'Dinosaur Jr.',
#   'Grizzly Bear'),
#  ('Beyonce',
#   'Kelly Clarkson',
#   'Panic! At The Disco',
#   'Sergio Contreras',
#   'Mary J. Blige',
#   'El sueno de Morfeo'),
#  ('Philip Grange', 'Kenneth Hesketh', 'Michael Ball', 'Joseph Phibbs'),
#  ('Lil Wil',
#   'Hurricane Chris',
#   'Yung Joc featuring Bun B & Young Dro',
#   'Dorrough',
#   'FREAK NASTY PRESENTS VARIOUS ARTIST'),
#  ('Monica Naranjo', 'Anastacia', 'Fall Out Boy', 'Jesse McCartney'),
#  ('American Music Club',
#   'Blitzen Trapper',
#   'The Breeders',
#   'TV On The Radio',
#   'Nick Cave & The Bad Seeds',
#   'Deerhunter',
#   'Lambchop'),
#  ('Midnight Juggernauts',
#   'Elbow',
#   'The Black Dog',
#   'Ital Tek',
#   'Johann Johannsson',
#   'Bersarin Quartett',
#   'Amon Amarth'),
#  ('Rush',
#   'Jethro Tull',
#   'Deep Purple',
#   'Soundgarden',
#   'Yes',
#   'Rainbow',
#   'Black Sabbath',
#   'Van Halen'),
#  ('Mariah Carey',
#   'Young Money',
#   'Justin Timberlake',
#   'Daniel Merriweather',
#   'Monica',
#   'B.o.B.',
#   'Jay-Z'),
#  ('Diddy Dirty Money',
#   'Jeremih',
#   'Faith Evans',
#   'J. Cole',
#   'Ne-Yo',
#   'Bruno Mars',
#   'Keri Hilson'),
#  ('Childish Gambino',
#   'Foster The People',
#   'J. Cole',
#   'Wale',
#   'Mac Miller',
#   'JAY Z',
#   'Drake',
#   'Kanye West'),
#  ('Stephen Malkmus & The Jicks',
#   'Real Estate',
#   'Cymbals Eat Guitars',
#   'The War On Drugs',
#   'Fleet Foxes',
#   'Jeff The Brotherhood',
#   'The Antlers'),
#  ('Austra',
#   'Joe Goddard',
#   'The Rapture',
#   'Gang Gang Dance',
#   'Suuns',
#   'Com Truise',
#   'Metronomy',
#   'Lana Del Rey',
#   'SBTRKT'),
#  ('Anna Calvi', 'Ghostpoet', 'James Blake', 'Everything Everything', 'Elbow'),
#  ('The Black Eyed Peas',
#   'Bruno Mars',
#   'Adele',
#   'Beyonce',
#   'Bob Marley & the Wailers'),
#  ('Gerry Rafferty',
#   'Martin Solveig',
#   'Eminem',
#   'Quantic',
#   'Alexandra Stan',
#   'Cafe Con Leche',
#   'Mike Jules',
#   'Enrico Perez',
#   'Dawn Penn'),
#  ('RJD2',
#   'Chase & Status',
#   'Ratatat',
#   'M83',
#   'AWOLNATION',
#   'Turin Brakes',
#   'Seasick Steve'),
#  ('Youth Lagoon',
#   'Crystal Castles',
#   'The Drums',
#   'Real Estate',
#   'Gotye',
#   'Cover Nation'),
#  ('The Chap',
#   'John Talabot',
#   'Todd Terje',
#   'This Many Boyfriends',
#   'Errors',
#   'The 2 Bears',
#   'Scuba',
#   'I:Cube',
#   'Pulled Apart By Horses'),
#  ('Juicy J',
#   'Nicki Minaj',
#   '2 Chainz',
#   'A$AP Rocky',
#   'DJ Scream',
#   'Kanye West',
#   'DJ Drama',
#   'Jeezy'),
#  ('Audra McDonald',
#   'Andy Taylor',
#   'Steve Kazee',
#   'Newsies - Original Broadway Cast',
#   'Elizabeth A. Davis',
#   'Once Ensemble',
#   'Cristin Milioti',
#   'Will Connolly'),
#  ('Shane & Shane',
#   'Hillsong Worship',
#   'Hillsong United',
#   'Hillsong',
#   'Kari Jobe'),
#  ('Thomas Newman',
#   'Beastie Boys',
#   'Radiohead',
#   'JAY Z',
#   'Massive Attack',
#   'Vangelis',
#   'Propellerheads',
#   'Hans Zimmer',
#   'Bat For Lashes'),
#  ('One Self',
#   'Crystal Fighters',
#   'Meat Puppets',
#   'Parov Stelar',
#   'Godspeed You! Black Emperor',
#   'Camille Yarbrough',
#   'Harley Poe'),
#  ('Automatic Tasty', 'Of Monsters and Men', 'Chris Knox', 'Underworld'),
#  ('The Honorary Title',
#   'Straylight Run',
#   'Dear and the Headlights',
#   'Manchester Orchestra',
#   'Brand New',
#   'Steel Train',
#   'The Format',
#   'Cassino & Laben'),
#  ('Jacqueline Taieb',
#   'Norah Jones',
#   'The Dave Brubeck Quartet',
#   'Frank Sinatra',
#   'Tony Mottola'),
#  ('Gareth Dickson',
#   'Kane Ikin',
#   'Between',
#   'Stephan Mathieu',
#   'Taylor Deupree',
#   'Simon Scott'),
#  ('Hey Monday',
#   'We The Kings',
#   'The Maine',
#   'Cobra Starship',
#   'Every Avenue',
#   'The Cab',
#   'Tonight Alive'),
# ...
#   'PowerSolo',
#   'Pete And The Pirates',
#   'Carina Round',
#   'Son Lux',
#   'Mirah',
#   'Bernard Herrmann',
#   'Patience & Prudence'),
#  ('All Time Low',
#   'Sleeping With Sirens',
#   'Pierce The Veil',
#   'Steve Aoki',
#   'Arctic Monkeys',
#   'John Mayer',
#   'John Legend',
#   'Two Door Cinema Club',
#   'Fall Out Boy'),
#  ('Ellen Allien',
#   'Aaliyah',
#   'Crystal Castles',
#   'Snoop Dogg',
#   'Kanye West',
#   'Justin Timberlake',
#   'Sleigh Bells',
#   'The xx',
#   'Ying Yang Twins'),
#  ('Rodriguez',
#   'Rufus Wainwright',
#   'Nino Bravo',
#   'Sam Morrison and Turn The Page',
#   'Cat Stevens'),
#  ('U2', 'La Roux', 'Black Eyed Peas', 'Passion Pit'),
#  ('Alaska Y Dinarama',
#   'Queen',
#   'Alaska Y Los Pegamoides',
#   'Fangoria',
#   'Dinarama + Alaska',
#   'Alaska'),
#  ('Alex Ubago', 'El sueno de Morfeo', 'Brito', 'Craig David'),
#  ('Miles Davis',
#   'Duke Ellington',
#   'David Mengual',
#   'Duke Ellington & John Coltrane',
#   'Etta James'),
#  ('Tage Danielsson',
#   'Anders Lundin',
#   'Mats Radberg',
#   'Kina Carina Jaarnek',
#   'Jokkmokks Jokke'),
#  ('Segundo Piso', 'Julio Sol', 'Luis Guinea', 'Louisiana'),
#  ('Tea Leaf Green',
#   'ALO (Animal Liberation Orchestra)',
#   'Ben Harper',
#   'Eddie Vedder',
#   'Ben Harper And The Innocent Criminals'),
#  ('Britney Spears',
#   'Jessie J',
#   'Nicki Minaj',
#   'Glee Cast',
#   'Marina and The Diamonds',
#   'Selena Gomez & The Scene'),
#  ('Rick Ross', 'Lil Wayne', 'The Game', 'JAY Z', 'Tyga'),
#  ('Fabio',
#   'Chico y Chica',
#   'La Prohibida',
#   'Hidrogenesse',
#   'Algora',
#   'La Casa Azul'),
#  ('Lily Allen',
#   'Cream',
#   'Otis Redding',
#   'Joss Stone',
#   'Stevie Wonder',
#   'Bruce Springsteen',
#   'Jimi Hendrix'),
#  ('Dirty Projectors',
#   'Hot Chip',
#   'Death Grips',
#   'Luke Abbott',
#   'Al Green',
#   'Parades',
#   'Zomby/Reark',
#   'TV On The Radio',
#   'Talking Heads'),
#  ('Joy Division',
#   'Love',
#   'Emeralds',
#   'Fang Island',
#   'POLICA',
#   'Mos Def',
#   'Nick Cave & The Bad Seeds',
#   'Every Time I Die',
#   'The Blondes'),
#  ("Jack's Mannequin",
#   'Something Corporate',
#   'Andrew McMahon',
#   'Andrew McMahon in the Wilderness'),
#  ('TLC',
#   'Ace of Base',
#   '50 Cent',
#   'Dangerous Minds Music from the Motion Picture',
#   'Marky Mark And The Funky Bunch',
#   'Vanilla Ice',
#   'Montell Jordan',
#   'MC Hammer'),
#  ('Robyn', 'Madonna', 'Icona Pop', 'Kings Of Leon', 'Portishead'),
#  ('Antonio Vega - [EMG]', 'Antonio Vega', 'Nacha Pop', 'antonio vega'),
#  ('Cobra Starship',
#   'Owl City',
#   'Pharrell Williams',
#   'Train',
#   'Steve Winwood',
#   'Carly Rae Jepsen',
#   "Des'ree",
#   'Bridgit Mendler',
#   'Katy Perry'),
#  ('Breakbot',
#   'Liars',
#   'Hot Chip',
#   'The xx',
#   'Tame Impala',
#   'Alabama Shakes',
#   'Lescop'),
#  ('A$AP Twelvy',
#   'A$AP Rocky',
#   'ASAP Rocky & ASAP Ant',
#   'A$AP Ferg',
#   'A$AP Mob',
#   'ASAP Ferg',
#   'A$AP Ant/Milo'),
#  ('The Hotelier',
#   'The War On Drugs',
#   'Punch',
#   'Pianos Become The Teeth',
#   'Single Mothers',
#   'Jessie Ware',
#   'Copeland'),
#  ('All Time Low',
#   'New Found Glory',
#   'blink-182',
#   'Sleeping With Sirens',
#   'Mayday Parade',
#   'Joan Jett',
#   'A Day To Remember',
#   'Fall Out Boy',
#   'Paramore'),
#  ('Suuns',
#   'Bosse-de-Nage',
#   'Godspeed You! Black Emperor',
#   'The Wombats',
#   'Lower Dens',
#   'A Place To Bury Strangers'),
#  ('Flo Rida',
#   'House South Brothers',
#   'Buraka Som Sistema',
#   'Michael Jackson',
#   'We Are Standard'),
#  ('Aretha Franklin',
#   'Tony Bennett',
#   'George Michael',
#   'The Blues Brothers',
#   'Eurythmics'),
#  ('Marilyn Manson',
#   'Nine Inch Nails',
#   'Deftones',
#   'Rage Against The Machine',
#   'M.I.A.'),
#  ('Parov Stelar', 'Joan Baez', 'Phoenix', 'Luisa Sobral', 'Gecko Turner'),
#  ('Sisters Of Mercy',
#   'The White Stripes',
#   'Dead Can Dance',
#   'Joy Division',
#   'The Smiths'),
#  ('Asa', 'Yael Naim', 'Ayo', 'Selah Sue', 'Selah Sue (feat. Cee-Lo Green)'),
#  ('Mellowdrone',
#   'Solid Gold',
#   'Glass Animals',
#   'Phantogram',
#   'Junior Boys',
#   'Mackintosh Braun',
#   'Sebastien Tellier'),
#  ('Samuel Barber',
#   'Pantera',
#   'Vitamin String Quartet',
#   'John Murphy',
#   'Pentatonix',
#   'Howard Shore'),
#  ('Africa Djembe Orchestra',
#   'Daft Punk',
#   'William Fitzsimmons',
#   'Ennio Morricone',
#   'Alexandrov Choir',
#   'Hank McCainone',
#   'A.R. Rahman',
#   'fat segal'),
#  ('Desert Noises',
#   'Humming House',
#   'Jamestown Revival',
#   'little hurricane',
#   'Wild Child'),
#  ('Eric Whitacre',
#   'Frequency',
#   'Felice Anerio',
#   'Traditional',
#   'Ivo Antognini',
#   'Ola Gjeilo'),
#  ('Blessthefall',
#   'Lecrae',
#   'Pierce the Veil',
#   'The Wedding',
#   'Before Their Eyes'),
#  ('Vic Chesnutt',
#   'Kenny Wheeler',
#   'Bill Frisell and Ferd Hersch',
#   'Bill Frisell',
#   'Arthur Blythe'),
#  ('Ivete Sangalo',
#   'Babado Novo',
#   'Jammil',
#   'Don Omar',
#   'Iran Costa',
#   'Psirico',
#   'Claudia Leitte'),
#  ('Tinariwen', 'Riptide', 'What So Not', 'Little Dragon', 'Mumdance'),
#  ('Ja Rule',
#   'Ludacris',
#   'Beyonce',
#   'Missy Elliott',
#   'UGK',
#   'Pitbull',
#   'DJ Snake',
#   'T.I.'),
#  ('Pacific Air',
#   'Parov Stelar',
#   'C2C',
#   'Parov Stelar Trio',
#   'Lana Del Rey',
#   'Lilja Bloom',
#   'Metrik'),
#  ('Beyonce', 'Example', 'Justin Timberlake', 'Arctic Monkeys'),
#  ('Mother Mother',
#   'Pacific Air',
#   'Major Lazer',
#   'Miracle Fortress',
#   'Tanlines',
#   'Faces',
#   'The Neighbourhood',
#   'Say Hi',
#   'St. Lucia'),
#  ('Aaliyah',
#   'The Teddybears',
#   'United Ladies Of Soul',
#   'The Birthday Bunch',
#   'Timbland and Magoo',
#   'Timbaland & Magoo',
#   'Nas featuring Aaliyah'),
#  ('Aaliyah', 'Missy Elliott', 'Ginuwine', 'Timbaland'),
#  ('AaRON', 'Aaron', 'Aaron Watson', 'George Strait'),
#  ('Aaron Carter', 'T.Lyle$', 'Lee Gardner', 'Cole Jonson', 'AP9'),
#  ('Aaron Parks',
#   'Matt Brewer',
#   'Kendrick Scott',
#   'Orlando Leflemming',
#   'Lage Lund',
#   'Mike Moreno'),
#  ('Aaron Thomas', 'Deluxe', 'Los Hermanos Dalton', 'Gloria Trevi'),
#  ('Ab-Soul', 'Kendrick Lamar', 'Nitty Scott, MC', 'Black Hippy'),
#  ('ABBA', 'Amanda Seyfried', 'Colin Firth', 'Meryl Streep'),
#  ('Bjorn Ulvaeus', 'Agnetha Faltskog', 'Frida', 'ABBA'),
#  ('Ed Sheeran', 'One Direction', 'Bastille', 'Jessie J'),
#  ('Pantera',
#   'Linkin Park',
#   'Boyce Avenue',
#   'U2',
#   'Staind',
#   'Shinedown',
#   'Rascal Flatts',
#   'Megadeth'),
#  ('Kishore Kumar',
#   'Asha Bhosle',
#   'R. D. Burman',
#   'Manna Dey',
#   'Mohammed Rafi',
#   'Lata Mangeshkar'),
#  ('Shigeru Umebayashi',
#   'Abel Korzeniowski',
#   'Jo Stafford',
#   "Booker T. & The MG's",
#   'Miriam Gauci',
#   'Etta James',
#   'Steve Cropper',
#   'Alfredo Catalani',
#   'Bernard Herrmann'),
#  ('Shigeru Umebayashi',
#   'Abel Korzeniowski',
#   'Jo Stafford',
#   "Booker T. & The MG's",
#   'Miriam Gauci',
#   'Etta James'),
#  ('Katy Perry', 'OneRepublic', 'Eminem', 'Swedish House Mafia'),
#  ('Jessie J',
#   'J. Cole',
#   'Katy Perry',
#   'Taylor Swift',
#   'SoMo',
#   'The Yesteryears'),
#  ('Tricky', 'Portishead', 'Massive Attack', 'Zero 7'),
#  ('Empire Of The Sun',
#   'Basement Jaxx',
#   'Daft Punk',
#   'Jimmy Eat World',
#   'James Blake'),
#  ('Stevie Wonder',
#   'Bill Frisell',
#   'Nat King Cole',
#   'Paul McCartney',
#   'Mose Allison'),
#  ('Sweet Pea Atkinson', 'Blur', 'Chip E.', 'Slave'),
#  ('Robert Schumann',
#   'Johann Sebastian Bach',
#   'Yo-Yo Ma',
#   'George Frideric Handel'),
#  ('Anamanaguchi',
#   'Darren Korb',
#   'Jim Guthrie',
#   'Mux Mool',
#   'M|O|O|N',
#   'Jonathan Coulton',
#   'FantomenK'),
#  ('Example',
#   'Boyce Avenue',
#   'Green Day',
#   'Tinie Tempah',
#   'Olly Murs',
#   'The Script',
#   'Swedish House Mafia'),
#  ('David Russell',
#   'Manuel Ponce',
#   'Fernando Sor',
#   'Pascal Boels',
#   'Franz Schubert',
#   'Frederic Chopin',
#   'Mauro Giuliani',
#   'Felix Mendelssohn',
#   'Wolfgang Amadeus Mozart'),
#  ('Sir Neville Marriner',
#   'Academy of St. Martin-in-the-Fields/Celia Nicklin/Ian Watson/Sir Neville Marriner',
#   'Academy of St Martin-in-the-Fields/Ian Watson/Sir Neville Marriner',
#   'Academy of St. Martin-in-the-Fields/Paul Davies/Sir Neville Marriner',
#   'Academy of St. Martin in the Fields',
#   'Academy of St Martin-in-the-Fields/Kenneth Sillito/Denis Vigay/Sir Neville Marriner'),
#  ('The ZOE Group',
#   'Hallal Music',
#   'Discovery Singers',
#   'Gaither Vocal Band',
#   'The Isaacs'),
#  ('Hillsong Worship', 'August Burns Red', 'The Almost', 'N Sync'),
#  ('Counting Crows', 'Mat Kearney', 'Van Morrison', 'Fruit Bats'),
#  ('Acda en de Munnik',
#   "De Poema's",
#   'Keizer & De Munnik',
#   'Thomas Acda',
#   'Nick',
#   'Paul de Munnik'),
#  ('Acda en de Munnik', "De Poema's", 'Keizer & De Munnik', 'Nick'),
#  ('Curtis Mayfield', 'Bobby Womack', 'Marlena Shaw', 'Aretha Franklin', 'Can'),
#  ('Ace of Base', 'Land Down Under', 'Colin Hay', 'Rico Bernasconi'),
#  ('Vampire Weekend',
#   'Grouplove',
#   'Matt and Kim',
#   'Edward Sharpe & The Magnetic Zeros',
#   'Death Cab for Cutie',
#   'Of Monsters and Men',
#   'Young the Giant',
#   'The Strokes',
#   'The Shins'),
#  ('Andy Irvine', 'Sandy Denny', 'Atahualpa Yupanqui', 'Satya Sai Baba'),
#  ('Kirika',
#   'Cenk Erdogan',
#   'Riff Cohen',
#   'Norrda',
#   'Zoe Viccaji',
#   'Adamlar',
#   'Mehmet Gureli',
#   'Gevende',
#   'Club des Belugas'),
#  ('Richard Galliano',
#   'Richard Galliano, Paolo Fresu & Jan Lundgren',
#   'Johann Sebastian Bach',
#   'Daniel Mille',
#   'Paolo Fresu, Richard Galliano & Jan Lundgren',
#   'Jan Lundgren, Paolo Fresu & Richard Galliano'),
#  ("Keb' Mo'",
#   'Bowling Green John Cephas & Harmonica Phil Wiggins',
#   'Kelly Joe Phelps',
#   'Stevie Ray Vaughan',
#   'Rory Block',
#   'Eric Bibb'),
#  ('Steve Erquiaga',
#   'Various Artists',
#   'Our Daily Bread',
#   'Steve Morse',
#   'Sean Harkness',
#   'Will Ackerman',
#   'Tuck Andress',
#   'Alex de Grassi'),
#  ('Joan Baez',
#   'T-Bone Walker',
#   'Leonard Cohen',
#   'Sufjan Stevens',
#   'Mississippi John Hurt',
#   'Crosby, Stills, Nash & Young',
#   'Zella Day',
#   'Diana Krall',
#   'Simon & Garfunkel'),
#  ('LIGHTS',
#   'Angus & Julia Stone',
#   'Boyce Avenue',
#   'Howie Day',
#   'John Mayer',
#   'Metric',
#   'Tyler Ward feat. Heather Janssen',
#   'Jose Gonzalez',
#   'Tyler Hilton'),
#  ('Matthew Koma',
#   'The Gaslight Anthem',
#   'Anthem Lights',
#   'The Starting Line',
#   'Will Hoge'),
#  ('Phil Keaggy',
#   'Peter Fletcher (guitar)',
#   'Christopher Parkening',
#   'Ole Staveteig',
#   'The Acoustic Guitar Troubadours',
#   'Frode Alns'),
#  ('Shinedown',
#   'Daniel Powter',
#   'Jack Johnson',
#   'Jake Bugg',
#   'James Blunt',
#   'Bruno Mars',
#   'Take That'),
#  ('Hello Seahorse!', 'Deftones', 'The Coral', 'Natalia Lafourcade'),
#  ('Alejandra Guzman', 'Donavon Frankenreiter', 'Zoe', 'Stereo Dub'),
#  ('Lifehouse', 'Bright Eyes', 'Phillip Phillips', 'Jason Mraz'),
#  ('Citizen',
#   'Real Friends',
#   'Defeater',
#   'The Wonder Years',
#   'Modern Baseball'),
#  ('George Strait',
#   'Various Artists - Creedence Clearwater Revival Tribute',
#   'Hello',
#   'John Denver',
#   'Interpol'),
#  ('Dave Matthews Band',
#   'Coldplay',
#   'Hilary Duff',
#   'OneRepublic',
#   'Imagine Dragons',
#   'Pearl Jam',
#   'Zoe',
#   'Lorde',
#   'Mark Ronson'),
#  ('Vetusta Morla',
#   'Supersubmarina',
#   'Texas',
#   'Joe la Reina',
#   'Fuel Fandango',
#   'Monica Naranjo',
#   "O'Funk'illo",
#   'Inocua',
#   'The Excitements'),
#  ('A Day To Remember',
#   'You Me At Six',
#   'Avenged Sevenfold',
#   'Bowling For Soup',
#   'Stone Sour'),
#  ('Holden', 'Lynda', 'Justin Bieber', 'Enya'),
#  ('Dean Martin',
#   'Paolo Nutini',
#   'Ella Fitzgerald',
#   'Chicane',
#   'Frank Sinatra',
#   'The Cranberries'),
#  ('Mikael Jonasson',
#   'Manic Brothers',
#   'Patrick Siech',
#   'Ida Engberg',
#   'Adam Beyer',
#   'Joel Mull',
#   'Petter B',
#   'Cari Lekebusch'),
#  ('Adam Levine',
#   'Slash',
#   'Gym Class Heroes',
#   'Alicia Keys',
#   'The Lonely Island'),
#  ('Jars Of Clay', 'The Afters', 'Adam Sams', 'Chad Barela'),
#  ('DJ Jazzy Jeff & The Fresh Prince',
#   'Halloween Music',
#   'Michael Jackson',
#   'DJ Remix Factory'),
#  ('Meghan Trainor',
#   'Jessie J',
#   'Ariana Grande',
#   'Sia',
#   'Florida Georgia Line',
#   'Iggy Azalea',
#   'Maroon 5',
#   'Taylor Swift'),
#  ('Nick Carter',
#   'Robert Palmer',
#   'Weird Al Yankovic',
#   'Madonna',
#   'Natalie Imbruglia'),
#  ('Adele', 'The Avener & Phoebe Killdeer', 'The Avener', 'GMPresents'),
#  ('Hugh Laurie',
#   'Juliette Lewis',
#   'Beyond The Sea - Kevin Spacey',
#   'She & Him',
#   'Milla Jovovich',
#   'Robbie Williams'),
#  ('Thomas Ades/Susan Bickley/City of Birmingham Symphony Orchestra/City of Birmingham Symphony Chorus',
#   'Endellion String Quartet',
#   'Thomas Ades/Birmingham Contemporary Music Group',
#   'Thomas Ades',
#   'London Sinfonietta/Markus Stenz',
#   'Thomas Ades/Arditti Quartet',
#   'Thomas Ades/City of Birmingham Symphony Orchestra',
#   'Thomas Ades/Anthony Marwood/Chamber Orchestra of Europe'),
#  ('Attack Attack!',
#   'Adestria',
#   'In Fear And Faith',
#   'Alesana',
#   'The Devil Wears Prada',
#   'A.F.I.'),
#  ('Womack & Womack',
#   'Amel Larrieux',
#   'Cocteau Twins',
#   'Sa-ra Creative Partners',
#   'Letta Mbulu'),
#  ('Karl Jenkins/London Symphony Orchestra/Mae McKenna/Synergy Vocals',
#   'Karl Jenkins/London Symphony Orchestra',
#   "Karl Jenkins/London Symphony Orchestra/Synergy Vocals/New London Children's Choir",
#   'Karl Jenkins/London Symphony Orchestra/Synergy Vocals',
#   'Karl Jenkins/London Symphony Orchestra/Mae McKenna',
#   'Karl Jenkins/London Symphony Orchestra/Belinda Sykes',
#   "Karl Jenkins/London Symphony Orchestra/New London Children's Choir",
#   "Karl Jenkins/London Symphony Orchestra/Mae McKenna/New London Children's Choir"),
#  ('Erasure',
#   'The Cure',
#   'Bad Boys Blue',
#   'A Flock Of Seagulls',
#   'Real Life',
#   'Information Society'),
#  ('Toto', 'Daniel Martin Moore', 'The Avett Brothers', 'Ben Solee'),
#  ('Casting Crowns',
#   'Jaime Salmoreno',
#   'Marcos Vidal',
#   'Hermana Glenda',
#   'Alejandra Hernandez',
#   'Tierra de bendicion',
#   'Jesus Adrian Romero',
#   'La voz del desierto',
#   'Abel Zavala'),
#  ('Mustasch',
#   'Self',
#   'The Raconteurs',
#   'The Roots',
#   'Aesop Rock',
#   'Johnny Blaze',
#   'Street Life',
#   'Taprikk Sweezee',
#   'OutKast'),
#  ('Joe Venuti',
#   'Adrian Rollini And His Orchestra',
#   'Adrian Rollini',
#   'Adrian Rollini And His Friends',
#   'The Goofus Five',
#   'Louisiana Rhythm Kings',
#   'The Golden Gate Orchestra',
#   'Bert Lown And His Orchestra',
#   'Bert Lown Orchestra'),
#  ('Tricky', 'Francesca Belmonte', 'A.J.', 'Silvertongue'),
#  ('Jack Johnson',
#   'John Mayer',
#   'Coldplay',
#   'Jason Mraz',
#   'Lucy Kaplansky',
#   'Stevie Wonder'),
#  ('Flume', 'Pearl Jam', 'NOFX', 'Lenzman', 'Bo Saris'),
#  ('Shinedown', 'Boyce Avenue', 'Staind', 'Rascal Flatts', 'Megadeth'),
#  ('Supergrass',
#   'Jessie J',
#   'Mother Mother',
#   'New Order',
#   'The Lumineers',
#   'Imagine Dragons',
#   'Passenger',
#   'OneRepublic',
#   'Radical Face'),
#  ('Young the Giant',
#   'Radiohead',
#   'The Kooks',
#   'Dropkick Murphys',
#   'Brand New',
#   'Modest Mouse',
#   'Death Cab for Cutie'),
#  ('ArkA-9', 'Adventure Time', 'Marcus Coronel', 'SLevin', 'Chetreo'),
#  ('Robbie Williams',
#   'The xx',
#   'Coldplay',
#   'Daft Punk',
#   'Justin Timberlake',
#   'Kavinsky',
#   'The Raconteurs',
#   'Pepe Willberg',
#   'Lieminen'),
#  ('Thomas Ades/Susan Bickley/City of Birmingham Symphony Orchestra/City of Birmingham Symphony Chorus',
#   'Thomas Ades/Christopher Maltman/City of Birmingham Symphony Orchestra',
#   'Thomas Ades/Composers Ensemble',
#   'Stephen Layton/Polyphony/Christopher Bowers-Broadbent/Tom Poster/Hugh Webb/Richard Benjafield',
#   'Stephen Layton/Polyphony/Christopher Bowers-Broadbent',
#   'Thomas Ades/Claron McFadden/Composers Ensemble',
#   'Stephen Layton/Polyphony',
#   'Robin Blaze/Huw Watkins'),
#  ('Aerosmith',
#   'RUN-DMC',
#   'Steven Tyler',
#   "Aerosmith featuring Sierra Leone's Refugee All Stars",
#   'Don Henley',
#   'Yes',
#   'Studio 99'),
#  ('Aerosmith',
#   'Whitford/St. Holmes',
#   'The Joe Perry Project',
#   'ChainReaction'),
#  ('Shaka Ponk', 'Grimes', 'Aesthetic Perfection', 'The Byrds', 'Combichrist'),
#  ('Absynthe Minded', 'Jasper Erkens', 'Pearl Jam', 'Snow Patrol'),
#  ('Dobet Gnahore',
#   'AfroCubism',
#   'Monks Of Senegal',
#   'Instrumental et choeur senegalais de Keur Moussa'),
#  ('Licky',
#   'Ofo The Black Company',
#   'Ladysmith Black Mambazo',
#   'Cheikh Lo',
#   'Brenda Fassie'),
#  ('Meiway', '9ice', 'Papa Wemba', 'Pepe Kalle'),
#  ('Afrika Bambaataa & The Soul Sonic Force',
#   'Afrika Bambaataa & Soul Sonic Force with Shango',
#   'Afrika Bambaataa & The Jazzy 5',
#   'Afrika Bambaataa & James Brown',
#   'Afrika Bambaataa',
#   'Afrika Bambaataa Nation Cosmic Force',
#   'Afrika Bambaataa Nation Soul Sonic Force'),
#  ...]

# %%
len(listArtist)
# Out:
# 17024

# %% [markdown]
# ### Model
# ----

# %%
# https://towardsdatascience.com/the-apriori-algorithm-5da3db9aea95

#pip install efficient-apriori
# Out:
# Collecting efficient-apriori
#   Downloading efficient_apriori-2.0.3-py3-none-any.whl (14 kB)
# Installing collected packages: efficient-apriori
# Successfully installed efficient-apriori-2.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from efficient_apriori import apriori

# our min support is 7, but it has to be expressed as a percentage for efficient-apriori
min_support = 2/len(listArtist) 

# min confidence allows you to delete rules with low confidence.
# For now set min_confidence = 0 to obtain all the rules
min_confidence = 0
itemsets, rules = apriori(listArtist, min_support=min_support, min_confidence=min_confidence)

# %%
rules
# Out:
# [{  } -> { },
#  { } -> {  },
#  {The Smashing Pumpkins} -> { (Crosses)},
#  { (Crosses)} -> {The Smashing Pumpkins},
#  {Daft Punk} -> {!!!},
#  {!!!} -> {Daft Punk},
#  {Hot Chip} -> {!!!},
#  {!!!} -> {Hot Chip},
#  {Jagwar Ma} -> {!!!},
#  {!!!} -> {Jagwar Ma},
#  {Kavinsky} -> {!!!},
#  {!!!} -> {Kavinsky},
#  {LCD Soundsystem} -> {!!!},
#  {!!!} -> {LCD Soundsystem},
#  {Angels & Airwaves} -> {+44},
#  {+44} -> {Angels & Airwaves},
#  {Box Car Racer} -> {+44},
#  {+44} -> {Box Car Racer},
#  {Taking Back Sunday} -> {+44},
#  {+44} -> {Taking Back Sunday},
#  {blink-182} -> {+44},
#  {+44} -> {blink-182},
#  {Yann Tiersen} -> {10,000 Maniacs},
#  {10,000 Maniacs} -> {Yann Tiersen},
#  {Blue Swede} -> {10cc},
#  {10cc} -> {Blue Swede},
#  {Redbone} -> {10cc},
#  {10cc} -> {Redbone},
#  {Thirty Seconds To Mars} -> {12 Stones},
#  {12 Stones} -> {Thirty Seconds To Mars},
#  {A$AP Rocky} -> {2 Chainz},
#  {2 Chainz} -> {A$AP Rocky},
#  {Chris Brown} -> {2 Chainz},
#  {2 Chainz} -> {Chris Brown},
#  {DJ Drama} -> {2 Chainz},
#  {2 Chainz} -> {DJ Drama},
#  {Danny Brown} -> {2 Chainz},
#  {2 Chainz} -> {Danny Brown},
#  {Drake} -> {2 Chainz},
#  {2 Chainz} -> {Drake},
#  {Eminem} -> {2 Chainz},
#  {2 Chainz} -> {Eminem},
#  {J. Cole} -> {2 Chainz},
#  {2 Chainz} -> {J. Cole},
#  {JAY Z} -> {2 Chainz},
#  {2 Chainz} -> {JAY Z},
#  {Kanye West} -> {2 Chainz},
#  {2 Chainz} -> {Kanye West},
#  {Kendrick Lamar} -> {2 Chainz},
#  {2 Chainz} -> {Kendrick Lamar},
#  {Lil Wayne} -> {2 Chainz},
#  {2 Chainz} -> {Lil Wayne},
#  {MGK} -> {2 Chainz},
#  {2 Chainz} -> {MGK},
#  {Meek Mill} -> {2 Chainz},
#  {2 Chainz} -> {Meek Mill},
#  {Nicki Minaj} -> {2 Chainz},
#  {2 Chainz} -> {Nicki Minaj},
#  {Rick Ross} -> {2 Chainz},
#  {2 Chainz} -> {Rick Ross},
#  {Rihanna} -> {2 Chainz},
#  {2 Chainz} -> {Rihanna},
#  {Snoop Dogg} -> {2 Chainz},
#  {2 Chainz} -> {Snoop Dogg},
#  {T.I.} -> {2 Chainz},
#  {2 Chainz} -> {T.I.},
#  {Teriyaki Boyz} -> {2 Chainz},
#  {2 Chainz} -> {Teriyaki Boyz},
#  {Trey Songz} -> {2 Chainz},
#  {2 Chainz} -> {Trey Songz},
#  {Twista} -> {2 Chainz},
#  {2 Chainz} -> {Twista},
#  {Wiz Khalifa} -> {2 Chainz},
#  {2 Chainz} -> {Wiz Khalifa},
#  {TobyMac} -> {21:03},
#  {21:03} -> {TobyMac},
#  {Charta 77} -> {23Till},
#  {23Till} -> {Charta 77},
#  {Kottgrottorna} -> {23Till},
#  {23Till} -> {Kottgrottorna},
#  {Strebers} -> {23Till},
#  {23Till} -> {Strebers},
#  {David Garrett} -> {2Cellos},
#  {2Cellos} -> {David Garrett},
#  {The Piano Guys} -> {2Cellos},
#  {2Cellos} -> {The Piano Guys},
#  {Walt Ribeiro} -> {2Cellos},
#  {2Cellos} -> {Walt Ribeiro},
#  {BIGBANG} -> {2NE1},
#  {2NE1} -> {BIGBANG},
#  {EXO-K} -> {2NE1},
#  {2NE1} -> {EXO-K},
#  {Girls' Generation} -> {2NE1},
#  {2NE1} -> {Girls' Generation},
#  {Muse} -> {2NE1},
#  {2NE1} -> {Muse},
#  {Wonder Girls} -> {2NE1},
#  {2NE1} -> {Wonder Girls},
#  {50 Cent} -> {2Pac},
#  {2Pac} -> {50 Cent},
#  {Blackstreet} -> {2Pac},
#  {2Pac} -> {Blackstreet},
#  {Bone Thugs-N-Harmony} -> {2Pac},
#  {2Pac} -> {Bone Thugs-N-Harmony},
#  {Busta Rhymes} -> {2Pac},
#  {2Pac} -> {Busta Rhymes},
#  {Cam'Ron} -> {2Pac},
#  {2Pac} -> {Cam'Ron},
#  {Coolio} -> {2Pac},
#  {2Pac} -> {Coolio},
#  {Diddy} -> {2Pac},
#  {2Pac} -> {Diddy},
#  {Dr. Dre} -> {2Pac},
#  {2Pac} -> {Dr. Dre},
#  {Drake} -> {2Pac},
#  {2Pac} -> {Drake},
#  {Eminem} -> {2Pac},
#  {2Pac} -> {Eminem},
#  {Fort Minor} -> {2Pac},
#  {2Pac} -> {Fort Minor},
#  {Freddie Gibbs} -> {2Pac},
#  {2Pac} -> {Freddie Gibbs},
#  {Funkmaster Flex} -> {2Pac},
#  {2Pac} -> {Funkmaster Flex},
#  {Ice Cube} -> {2Pac},
#  {2Pac} -> {Ice Cube},
#  {JAY Z} -> {2Pac},
#  {2Pac} -> {JAY Z},
#  {Junior M.A.F.I.A.} -> {2Pac},
#  {2Pac} -> {Junior M.A.F.I.A.},
#  {Kanye West} -> {2Pac},
#  {2Pac} -> {Kanye West},
#  {Kendrick Lamar} -> {2Pac},
#  {2Pac} -> {Kendrick Lamar},
#  {LL Cool J} -> {2Pac},
#  {2Pac} -> {LL Cool J},
#  {Lil Wayne} -> {2Pac},
#  {2Pac} -> {Lil Wayne},
#  {Lupe Fiasco} -> {2Pac},
#  {2Pac} -> {Lupe Fiasco},
#  {Makaveli} -> {2Pac},
#  {2Pac} -> {Makaveli},
#  {Michael Jackson} -> {2Pac},
#  {2Pac} -> {Michael Jackson},
#  {Miley Cyrus} -> {2Pac},
#  {2Pac} -> {Miley Cyrus},
#  {N.W.A.} -> {2Pac},
#  {2Pac} -> {N.W.A.},
#  {Nas} -> {2Pac},
#  {2Pac} -> {Nas},
#  {Nate Dogg} -> {2Pac},
#  {2Pac} -> {Nate Dogg},
#  {OutKast} -> {2Pac},
#  {2Pac} -> {OutKast},
#  {Raekwon} -> {2Pac},
#  {2Pac} -> {Raekwon},
#  {Snoop Dogg} -> {2Pac},
#  {2Pac} -> {Snoop Dogg},
#  {The Game} -> {2Pac},
#  {2Pac} -> {The Game},
#  {The Notorious B.I.G.} -> {2Pac},
#  {2Pac} -> {The Notorious B.I.G.},
#  {The Pharcyde} -> {2Pac},
#  {2Pac} -> {The Pharcyde},
#  {The Roots} -> {2Pac},
#  {2Pac} -> {The Roots},
#  {Wale} -> {2Pac},
#  {2Pac} -> {Wale},
#  {Warren G} -> {2Pac},
#  {2Pac} -> {Warren G},
#  {Westside Connection} -> {2Pac},
#  {2Pac} -> {Westside Connection},
#  {Bon Jovi} -> {3 Doors Down},
#  {3 Doors Down} -> {Bon Jovi},
#  {Default} -> {3 Doors Down},
#  {3 Doors Down} -> {Default},
#  {Cypress Hill} -> {311},
#  {311} -> {Cypress Hill},
#  {Dirty Heads} -> {311},
#  {311} -> {Dirty Heads},
#  {Jack Johnson} -> {311},
#  {311} -> {Jack Johnson},
#  {Sublime} -> {311},
#  {311} -> {Sublime},
#  {The Smashing Pumpkins} -> {311},
#  {311} -> {The Smashing Pumpkins},
#  {All Time Low} -> {3OH!3},
#  {3OH!3} -> {All Time Low},
#  {Cobra Starship} -> {3OH!3},
#  {3OH!3} -> {Cobra Starship},
#  {Katy Perry} -> {3OH!3},
#  {3OH!3} -> {Katy Perry},
#  {Panic! At The Disco} -> {3OH!3},
#  {3OH!3} -> {Panic! At The Disco},
#  {Rihanna} -> {3OH!3},
#  {3OH!3} -> {Rihanna},
#  {David Archuleta} -> {5 Seconds Of Summer},
#  {5 Seconds Of Summer} -> {David Archuleta},
#  {Ed Sheeran} -> {5 Seconds Of Summer},
#  {5 Seconds Of Summer} -> {Ed Sheeran},
#  {One Direction} -> {5 Seconds Of Summer},
#  {5 Seconds Of Summer} -> {One Direction},
#  {Sam Smith} -> {5 Seconds Of Summer},
#  {5 Seconds Of Summer} -> {Sam Smith},
#  {Taylor Swift} -> {5 Seconds Of Summer},
#  {5 Seconds Of Summer} -> {Taylor Swift},
#  {blink-182} -> {5 Seconds Of Summer},
#  {5 Seconds Of Summer} -> {blink-182},
#  {Aaliyah} -> {50 Cent},
#  {50 Cent} -> {Aaliyah},
#  {Afroman} -> {50 Cent},
#  {50 Cent} -> {Afroman},
#  {Bad Meets Evil} -> {50 Cent},
#  {50 Cent} -> {Bad Meets Evil},
#  {Chris Brown} -> {50 Cent},
#  {50 Cent} -> {Chris Brown},
#  {Ciara} -> {50 Cent},
#  {50 Cent} -> {Ciara},
#  {D12} -> {50 Cent},
#  {50 Cent} -> {D12},
#  {DMX} -> {50 Cent},
#  {50 Cent} -> {DMX},
#  {Dr. Dre} -> {50 Cent},
#  {50 Cent} -> {Dr. Dre},
#  {Drake} -> {50 Cent},
#  {50 Cent} -> {Drake},
#  {Eminem} -> {50 Cent},
#  {50 Cent} -> {Eminem},
#  {Fabolous} -> {50 Cent},
#  {50 Cent} -> {Fabolous},
#  {Ice Cube} -> {50 Cent},
#  {50 Cent} -> {Ice Cube},
#  {JAY Z} -> {50 Cent},
#  {50 Cent} -> {JAY Z},
#  {Ja Rule} -> {50 Cent},
#  {50 Cent} -> {Ja Rule},
#  {Jeremih} -> {50 Cent},
#  {50 Cent} -> {Jeremih},
#  {Lil Wayne} -> {50 Cent},
#  {50 Cent} -> {Lil Wayne},
#  {Lloyd Banks} -> {50 Cent},
#  {50 Cent} -> {Lloyd Banks},
#  {Ludacris} -> {50 Cent},
#  {50 Cent} -> {Ludacris},
#  {MC Hammer} -> {50 Cent},
#  {50 Cent} -> {MC Hammer},
#  {Makaveli} -> {50 Cent},
#  {50 Cent} -> {Makaveli},
#  {Meek Mill} -> {50 Cent},
#  {50 Cent} -> {Meek Mill},
#  {Michael Jackson} -> {50 Cent},
#  {50 Cent} -> {Michael Jackson},
#  {Mobb Deep} -> {50 Cent},
#  {50 Cent} -> {Mobb Deep},
#  {Nate Dogg} -> {50 Cent},
#  {50 Cent} -> {Nate Dogg},
#  {Nelly} -> {50 Cent},
#  {50 Cent} -> {Nelly},
#  {Obie Trice} -> {50 Cent},
#  {50 Cent} -> {Obie Trice},
#  {Pearl Jam} -> {50 Cent},
#  {50 Cent} -> {Pearl Jam},
#  {Rick Ross} -> {50 Cent},
#  {50 Cent} -> {Rick Ross},
#  {Shakira} -> {50 Cent},
#  {50 Cent} -> {Shakira},
#  {Skylar Grey} -> {50 Cent},
#  {50 Cent} -> {Skylar Grey},
#  {Slaughterhouse} -> {50 Cent},
#  {50 Cent} -> {Slaughterhouse},
#  {Snoop Dogg} -> {50 Cent},
#  {50 Cent} -> {Snoop Dogg},
#  {Spider Loc} -> {50 Cent},
#  {50 Cent} -> {Spider Loc},
#  {T.I.} -> {50 Cent},
#  {50 Cent} -> {T.I.},
#  {The Game} -> {50 Cent},
#  {50 Cent} -> {The Game},
#  {The Notorious B.I.G.} -> {50 Cent},
#  {50 Cent} -> {The Notorious B.I.G.},
#  {Tony Yayo} -> {50 Cent},
#  {50 Cent} -> {Tony Yayo},
#  {Trey Songz} -> {50 Cent},
#  {50 Cent} -> {Trey Songz},
#  {Warren G} -> {50 Cent},
#  {50 Cent} -> {Warren G},
#  {Weird Al Yankovic} -> {50 Cent},
#  {50 Cent} -> {Weird Al Yankovic},
#  {Westside Connection} -> {50 Cent},
#  {50 Cent} -> {Westside Connection},
#  {Yelawolf} -> {50 Cent},
#  {50 Cent} -> {Yelawolf},
#  {Young Buck} -> {50 Cent},
#  {50 Cent} -> {Young Buck},
#  {9th Prince} -> {60 Second Assassin},
#  {60 Second Assassin} -> {9th Prince},
#  {RZA} -> {60 Second Assassin},
#  {60 Second Assassin} -> {RZA},
#  {Massive Attack} -> {65daysofstatic},
#  {65daysofstatic} -> {Massive Attack},
#  {Brian Eno} -> {808 State},
#  {808 State} -> {Brian Eno},
#  {William Orbit} -> {808 State},
#  {808 State} -> {William Orbit},
#  {FPS Allstars} -> {8BitAllstars},
#  {8BitAllstars} -> {FPS Allstars},
#  {Level-Up} -> {8BitAllstars},
#  {8BitAllstars} -> {Level-Up},
#  {PixelMix} -> {8BitAllstars},
#  {8BitAllstars} -> {PixelMix},
#  {Players_Select} -> {8BitAllstars},
#  {8BitAllstars} -> {Players_Select},
#  {Square Form} -> {8BitAllstars},
#  {8BitAllstars} -> {Square Form},
#  {The Pixels} -> {8BitAllstars},
#  {8BitAllstars} -> {The Pixels},
#  {Ben Folds} -> {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash},
#  {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash} -> {Ben Folds},
#  {Ben Folds Five} -> {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash},
#  {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash} -> {Ben Folds Five},
#  {Ben Folds with Rufus Wainwright} -> {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash},
#  {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash} -> {Ben Folds with Rufus Wainwright},
#  {Ben Folds withthe West Australian Symphony Orchestra} -> {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash},
#  {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash} -> {Ben Folds withthe West Australian Symphony Orchestra},
#  {Ben Folds/Nick Hornby} -> {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash},
#  {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash} -> {Ben Folds/Nick Hornby},
#  {The Bens} -> {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash},
#  {8in8- Ben Folds, Amanda Palmer, Neil Gaiman and Damian Kulash} -> {The Bens},
#  {Coldcut} -> {9 Lazy 9},
#  {9 Lazy 9} -> {Coldcut},
#  {DJ Food} -> {9 Lazy 9},
#  {9 Lazy 9} -> {DJ Food},
#  {Funki Porcini} -> {9 Lazy 9},
#  {9 Lazy 9} -> {Funki Porcini},
#  {London Funk Allstars} -> {9 Lazy 9},
#  {9 Lazy 9} -> {London Funk Allstars},
#  {Peter Kruder} -> {9 Lazy 9},
#  {9 Lazy 9} -> {Peter Kruder},
#  {The Herbaliser} -> {9 Lazy 9},
#  {9 Lazy 9} -> {The Herbaliser},
#  {Up, Bustle & Out} -> {9 Lazy 9},
#  {9 Lazy 9} -> {Up, Bustle & Out},
#  {Atomic Kitten} -> {911},
#  {911} -> {Atomic Kitten},
#  {B*Witched} -> {911},
#  {911} -> {B*Witched},
#  {Blue} -> {911},
#  {911} -> {Blue},
#  {Five} -> {911},
#  {911} -> {Five},
#  {Honeyz} -> {911},
#  {911} -> {Honeyz},
#  {Liberty X} -> {911},
#  {911} -> {Liberty X},
#  {Backstreet Boys} -> {98o},
#  {98o} -> {Backstreet Boys},
#  {N Sync} -> {98o},
#  {98o} -> {N Sync},
#  {New Kids On The Block} -> {98o},
#  {98o} -> {New Kids On The Block},
#  {O-Town} -> {98o},
#  {98o} -> {O-Town},
#  {RZA} -> {9th Prince},
#  {9th Prince} -> {RZA},
#  {All Time Low} -> {A Day To Remember},
#  {A Day To Remember} -> {All Time Low},
#  {Avenged Sevenfold} -> {A Day To Remember},
#  {A Day To Remember} -> {Avenged Sevenfold},
#  {Fall Out Boy} -> {A Day To Remember},
#  {A Day To Remember} -> {Fall Out Boy},
#  {Limp Bizkit} -> {A Day To Remember},
#  {A Day To Remember} -> {Limp Bizkit},
#  {Man Overboard} -> {A Day To Remember},
#  {A Day To Remember} -> {Man Overboard},
#  {Miss May I} -> {A Day To Remember},
#  {A Day To Remember} -> {Miss May I},
#  {New Found Glory} -> {A Day To Remember},
#  {A Day To Remember} -> {New Found Glory},
#  {The Wonder Years} -> {A Day To Remember},
#  {A Day To Remember} -> {The Wonder Years},
#  {Three Days Grace} -> {A Day To Remember},
#  {A Day To Remember} -> {Three Days Grace},
#  {You Me At Six} -> {A Day To Remember},
#  {A Day To Remember} -> {You Me At Six},
#  {Real Life} -> {A Flock Of Seagulls},
#  {A Flock Of Seagulls} -> {Real Life},
#  {Soft Cell} -> {A Flock Of Seagulls},
#  {A Flock Of Seagulls} -> {Soft Cell},
#  {The Cure} -> {A Flock Of Seagulls},
#  {A Flock Of Seagulls} -> {The Cure},
#  {Alejandro Fernandez} -> {A Great Big World},
#  {A Great Big World} -> {Alejandro Fernandez},
#  {Christina Aguilera} -> {A Great Big World},
#  {A Great Big World} -> {Christina Aguilera},
#  {Christina Perri} -> {A Great Big World},
#  {A Great Big World} -> {Christina Perri},
#  {Coldplay} -> {A Great Big World},
#  {A Great Big World} -> {Coldplay},
#  {Ed Sheeran} -> {A Great Big World},
#  {A Great Big World} -> {Ed Sheeran},
#  {Emeli Sande} -> {A Great Big World},
#  {A Great Big World} -> {Emeli Sande},
#  {Jason Mraz} -> {A Great Big World},
#  {A Great Big World} -> {Jason Mraz},
#  {John Mayer} -> {A Great Big World},
#  {A Great Big World} -> {John Mayer},
#  {Lady Gaga} -> {A Great Big World},
#  {A Great Big World} -> {Lady Gaga},
#  {Miley Cyrus} -> {A Great Big World},
#  {A Great Big World} -> {Miley Cyrus},
#  {Passenger} -> {A Great Big World},
#  {A Great Big World} -> {Passenger},
#  {Sam Smith} -> {A Great Big World},
#  {A Great Big World} -> {Sam Smith},
#  {The Killers} -> {A Great Big World},
#  {A Great Big World} -> {The Killers},
#  {David Bowie} -> {A Perfect Circle},
#  {A Perfect Circle} -> {David Bowie},
#  {Deftones} -> {A Perfect Circle},
#  {A Perfect Circle} -> {Deftones},
#  {Marilyn Manson} -> {A Perfect Circle},
#  {A Perfect Circle} -> {Marilyn Manson},
#  {Nine Inch Nails} -> {A Perfect Circle},
#  {A Perfect Circle} -> {Nine Inch Nails},
#  {Pearl Jam} -> {A Perfect Circle},
#  {A Perfect Circle} -> {Pearl Jam},
#  {Rammstein} -> {A Perfect Circle},
#  {A Perfect Circle} -> {Rammstein},
#  {The Smashing Pumpkins} -> {A Perfect Circle},
#  {A Perfect Circle} -> {The Smashing Pumpkins},
#  {Tool} -> {A Perfect Circle},
#  {A Perfect Circle} -> {Tool},
#  {Casual} -> {A Plus},
#  {A Plus} -> {Casual},
#  {Del The Funky Homosapien} -> {A Plus},
#  {A Plus} -> {Del The Funky Homosapien},
#  {Hieroglyphics} -> {A Plus},
#  {A Plus} -> {Hieroglyphics},
#  {Pep Love} -> {A Plus},
#  {A Plus} -> {Pep Love},
#  {Pep Love and Jay Biz} -> {A Plus},
#  {A Plus} -> {Pep Love and Jay Biz},
#  {Souls Of Mischief} -> {A Plus},
#  {A Plus} -> {Souls Of Mischief},
#  {Pixie Lott} -> {A Rocket To The Moon},
#  {A Rocket To The Moon} -> {Pixie Lott},
#  {The Maine} -> {A Rocket To The Moon},
#  {A Rocket To The Moon} -> {The Maine},
#  {Beroshima} -> {A Shoreline Dream},
#  {A Shoreline Dream} -> {Beroshima},
#  {Ulrich Schnauss} -> {A Shoreline Dream},
#  {A Shoreline Dream} -> {Ulrich Schnauss},
#  {Ulrich Schnauss, Jonas Munk} -> {A Shoreline Dream},
#  {A Shoreline Dream} -> {Ulrich Schnauss, Jonas Munk},
#  {Beastie Boys} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Beastie Boys},
#  {DJ Kool} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {DJ Kool},
#  {Das EFX} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Das EFX},
#  {De La Soul} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {De La Soul},
#  {Digable Planets} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Digable Planets},
#  {Dr. Dre} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Dr. Dre},
#  {Eric B. & Rakim} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Eric B. & Rakim},
#  {Fugees} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Fugees},
#  {Gang Starr} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Gang Starr},
#  {JAY Z} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {JAY Z},
#  {Kanye West} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Kanye West},
#  {Lupe Fiasco} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Lupe Fiasco},
#  {Method Man} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Method Man},
#  {Nas} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Nas},
#  {Naughty By Nature} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Naughty By Nature},
#  {OutKast} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {OutKast},
#  {Pete Rock & C.L. Smooth} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Pete Rock & C.L. Smooth},
#  {Q-Tip} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Q-Tip},
#  {Q-Tip featuring Korn} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Q-Tip featuring Korn},
#  {Redman} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Redman},
#  {Souls Of Mischief} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {Souls Of Mischief},
#  {The Notorious B.I.G.} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {The Notorious B.I.G.},
#  {The Pharcyde} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {The Pharcyde},
#  {The Roots} -> {A Tribe Called Quest},
#  {A Tribe Called Quest} -> {The Roots},
#  {Codes In The Clouds} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Codes In The Clouds},
#  {Jon Hopkins} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Jon Hopkins},
#  {Nils Frahm} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Nils Frahm},
#  {Olafur Arnalds} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Olafur Arnalds},
#  {Oliveray} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Oliveray},
#  {Peter Broderick} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Peter Broderick},
#  {Rival Consoles} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {Rival Consoles},
#  {The British Expeditionary Force} -> {A Winged Victory for the Sullen},
#  {A Winged Victory for the Sullen} -> {The British Expeditionary Force},
#  {A$AP Mob} -> {A$AP Ferg},
#  {A$AP Ferg} -> {A$AP Mob},
#  {A$AP Rocky} -> {A$AP Ferg},
#  {A$AP Ferg} -> {A$AP Rocky},
#  {J. Cole} -> {A$AP Ferg},
#  {A$AP Ferg} -> {J. Cole},
#  {Jason Derulo} -> {A$AP Ferg},
#  {A$AP Ferg} -> {Jason Derulo},
#  {Kendrick Lamar} -> {A$AP Ferg},
#  {A$AP Ferg} -> {Kendrick Lamar},
#  {Pusha T} -> {A$AP Ferg},
#  {A$AP Ferg} -> {Pusha T},
#  {Rich Homie Quan} -> {A$AP Ferg},
#  {A$AP Ferg} -> {Rich Homie Quan},
#  {Rick Ross} -> {A$AP Ferg},
#  {A$AP Ferg} -> {Rick Ross},
#  {Schoolboy Q} -> {A$AP Ferg},
#  {A$AP Ferg} -> {Schoolboy Q},
#  {A$AP Rocky} -> {A$AP Mob},
#  {A$AP Mob} -> {A$AP Rocky},
#  {Beyonce} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Beyonce},
#  {Busta Rhymes} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Busta Rhymes},
#  {DJ Drama} -> {A$AP Rocky},
#  {A$AP Rocky} -> {DJ Drama},
#  {DJ Khaled} -> {A$AP Rocky},
#  {A$AP Rocky} -> {DJ Khaled},
#  {DMX} -> {A$AP Rocky},
#  {A$AP Rocky} -> {DMX},
#  {Drake} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Drake},
#  {Ellie Goulding} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Ellie Goulding},
#  {Eminem} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Eminem},
#  {Flo Rida} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Flo Rida},
#  {Frank Ocean} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Frank Ocean},
#  {J. Cole} -> {A$AP Rocky},
#  {A$AP Rocky} -> {J. Cole},
#  {JAY Z} -> {A$AP Rocky},
#  {A$AP Rocky} -> {JAY Z},
#  {Jeezy} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Jeezy},
#  {Joey Bada$$} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Joey Bada$$},
#  {Kanye West} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Kanye West},
#  {Kendrick Lamar} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Kendrick Lamar},
#  {Lil Wayne} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Lil Wayne},
#  {M83} -> {A$AP Rocky},
#  {A$AP Rocky} -> {M83},
#  {Macklemore & Ryan Lewis} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Macklemore & Ryan Lewis},
#  {Pia Mia} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Pia Mia},
#  {Pretty Lights} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Pretty Lights},
#  {Pusha T} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Pusha T},
#  {Rick Ross} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Rick Ross},
#  {Rihanna} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Rihanna},
#  {Schoolboy Q} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Schoolboy Q},
#  {Snow Patrol} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Snow Patrol},
#  {Tame Impala} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Tame Impala},
#  {The Game} -> {A$AP Rocky},
#  {A$AP Rocky} -> {The Game},
#  {Tyler, The Creator} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Tyler, The Creator},
#  {Wale} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Wale},
#  {Wiz Khalifa} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Wiz Khalifa},
#  {Zedd} -> {A$AP Rocky},
#  {A$AP Rocky} -> {Zedd},
#  {Alan Silvestri} -> {A*Teens},
#  {A*Teens} -> {Alan Silvestri},
#  {Elvis Presley} -> {A*Teens},
#  {A*Teens} -> {Elvis Presley},
#  {Mark Keali'i Ho'omalu} -> {A*Teens},
#  {A*Teens} -> {Mark Keali'i Ho'omalu},
#  {Wynonna} -> {A*Teens},
#  {A*Teens} -> {Wynonna},
#  {Duck Sauce} -> {A-Trak},
#  {A-Trak} -> {Duck Sauce},
#  {Mariachi Mexico} -> {A. Banderas & Los Lobos},
#  {A. Banderas & Los Lobos} -> {Mariachi Mexico},
#  {Mario Kirlis} -> {A. Seoane},
#  {A. Seoane} -> {Mario Kirlis},
#  {St. Vincent} -> {A.A. Bondy},
#  {A.A. Bondy} -> {St. Vincent},
#  {Juan Gabriel} -> {A.B. Quintanilla III},
#  {A.B. Quintanilla III} -> {Juan Gabriel},
#  {Amanda Espinoza} -> {A.J},
#  {A.J} -> {Amanda Espinoza},
#  {Deli} -> {A.J},
#  {A.J} -> {Deli},
#  {Diplomatic} -> {A.J},
#  {A.J} -> {Diplomatic},
#  {Farid Bilgin} -> {A.J},
#  {A.J} -> {Farid Bilgin},
#  {Honestly} -> {A.J},
#  {A.J} -> {Honestly},
#  {Kontrollbeatz} -> {A.J},
#  {A.J} -> {Kontrollbeatz},
#  {Mahsa} -> {A.J},
#  {A.J} -> {Mahsa},
#  {Pari} -> {A.J},
#  {A.J} -> {Pari},
#  {Francesca Belmonte} -> {A.J.},
#  {A.J.} -> {Francesca Belmonte},
#  {Silvertongue} -> {A.J.},
#  {A.J.} -> {Silvertongue},
#  {Tricky} -> {A.J.},
#  {A.J.} -> {Tricky},
#  {Anirudh Ravichander} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Anirudh Ravichander},
#  {Anu Malik} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Anu Malik},
#  {Asha Bhosle & A. R. Rahman} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Asha Bhosle & A. R. Rahman},
#  {Harris Jayaraj} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Harris Jayaraj},
#  {Ila Arun} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Ila Arun},
#  {Ilaiyaraaja} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Ilaiyaraaja},
#  {Jennifer Lopez} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Jennifer Lopez},
#  {K. S. Chithra} -> {A.R. Rahman},
#  {A.R. Rahman} -> {K. S. Chithra},
#  {Mychael Danna} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Mychael Danna},
#  {Nitin Sawhney} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Nitin Sawhney},
#  {Pritam} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Pritam},
#  {Roopkumar Rathod} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Roopkumar Rathod},
#  {Shaan} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Shaan},
#  {Sujata Trivedi} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Sujata Trivedi},
#  {Suresh Wadkar, Kavita Krishnamoorthy & A. R. Rahman} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Suresh Wadkar, Kavita Krishnamoorthy & A. R. Rahman},
#  {Yuvan Shankar Raja} -> {A.R. Rahman},
#  {A.R. Rahman} -> {Yuvan Shankar Raja},
#  {Bee Gees} -> {ABBA},
#  {ABBA} -> {Bee Gees},
#  {Blondie} -> {ABBA},
#  {ABBA} -> {Blondie},
#  {Britney Spears} -> {ABBA},
#  {ABBA} -> {Britney Spears},
#  {Diana Ross} -> {ABBA},
#  {ABBA} -> {Diana Ross},
#  {George Michael} -> {ABBA},
#  {ABBA} -> {George Michael},
#  {Katy Perry} -> {ABBA},
#  {ABBA} -> {Katy Perry},
#  {Kylie Minogue} -> {ABBA},
#  {ABBA} -> {Kylie Minogue},
#  {Madonna} -> {ABBA},
#  {ABBA} -> {Madonna},
#  {Michael Jackson} -> {ABBA},
#  {ABBA} -> {Michael Jackson},
#  {Queen} -> {ABBA},
#  {ABBA} -> {Queen},
#  {Robbie Williams} -> {ABBA},
#  {ABBA} -> {Robbie Williams},
#  {Sly & The Family Stone} -> {ABBA},
#  {ABBA} -> {Sly & The Family Stone},
#  {Texas} -> {ABBA},
#  {ABBA} -> {Texas},
#  {The Jam} -> {ABBA},
#  {ABBA} -> {The Jam},
#  {The Rolling Stones} -> {ABBA},
#  {ABBA} -> {The Rolling Stones},
#  {The Yesteryears} -> {ABBA},
#  {ABBA} -> {The Yesteryears},
#  {Orchestral Manoeuvres In The Dark} -> {ABC},
#  {ABC} -> {Orchestral Manoeuvres In The Dark},
#  {Prefab Sprout} -> {ABC},
#  {ABC} -> {Prefab Sprout},
#  {The Rock Masters} -> {AD/CD},
#  {AD/CD} -> {The Rock Masters},
#  {Grouplove} -> {AFI},
#  {AFI} -> {Grouplove},
#  {Kings Of Leon} -> {AFI},
#  {AFI} -> {Kings Of Leon},
#  {Motorhead} -> {AFI},
#  {AFI} -> {Motorhead},
#  {Papa Roach} -> {AFI},
#  {AFI} -> {Papa Roach},
#  {Yellowcard} -> {AFI},
#  {AFI} -> {Yellowcard},
#  {Aphex Twin} -> {AFX},
#  {AFX} -> {Aphex Twin},
#  {Buckner & Garcia} -> {AKB48},
#  {AKB48} -> {Buckner & Garcia},
#  {Henry Jackman} -> {AKB48},
#  {AKB48} -> {Henry Jackman},
#  {Kool & The Gang} -> {AKB48},
#  {AKB48} -> {Kool & The Gang},
#  {Owl City} -> {AKB48},
#  {AKB48} -> {Owl City},
#  {Rihanna} -> {AKB48},
#  {AKB48} -> {Rihanna},
#  {Skrillex} -> {AKB48},
#  {AKB48} -> {Skrillex},
#  {JAY Z} -> {AKI},
#  {AKI} -> {JAY Z},
#  {Labyrint} -> {AKI},
#  {AKI} -> {Labyrint},
#  {Ben Harper} -> {ALO (Animal Liberation Orchestra)},
#  {ALO (Animal Liberation Orchestra)} -> {Ben Harper},
#  {Eddie Vedder} -> {ALO (Animal Liberation Orchestra)},
#  {ALO (Animal Liberation Orchestra)} -> {Eddie Vedder},
#  {Mohit Chauhan} -> {ARIJIT SINGH},
#  {ARIJIT SINGH} -> {Mohit Chauhan},
#  {Nikhil Paul George} -> {ARIJIT SINGH},
#  {ARIJIT SINGH} -> {Nikhil Paul George},
#  {Papon} -> {ARIJIT SINGH},
#  {ARIJIT SINGH} -> {Papon},
#  {Pritam} -> {ARIJIT SINGH},
#  {ARIJIT SINGH} -> {Pritam},
#  {Kanye West} -> {ASTR},
#  {ASTR} -> {Kanye West},
#  {Band of Horses} -> {ATB},
#  {ATB} -> {Band of Horses},
#  {DJ Sammy} -> {ATB},
#  {ATB} -> {DJ Sammy},
#  {Dash Berlin} -> {ATB},
#  {ATB} -> {Dash Berlin},
#  {David Guetta} -> {ATB},
#  {ATB} -> {David Guetta},
#  {Deep Dish} -> {ATB},
#  {ATB} -> {Deep Dish},
#  {Ian van Dahl} -> {ATB},
#  {ATB} -> {Ian van Dahl},
#  {Markus Schulz} -> {ATB},
#  {ATB} -> {Markus Schulz},
#  {Sash!} -> {ATB},
#  {ATB} -> {Sash!},
#  {Tiesto} -> {ATB},
#  {ATB} -> {Tiesto},
#  {Banks} -> {AWOLNATION},
#  {AWOLNATION} -> {Banks},
#  {Capital Cities} -> {AWOLNATION},
#  {AWOLNATION} -> {Capital Cities},
#  {Chevelle} -> {AWOLNATION},
#  {AWOLNATION} -> {Chevelle},
#  {Chris Brown} -> {AWOLNATION},
#  {AWOLNATION} -> {Chris Brown},
#  {Coldplay} -> {AWOLNATION},
#  {AWOLNATION} -> {Coldplay},
#  {Daft Punk} -> {AWOLNATION},
#  {AWOLNATION} -> {Daft Punk},
#  {Death Cab for Cutie} -> {AWOLNATION},
#  {AWOLNATION} -> {Death Cab for Cutie},
#  {Dirty Heads} -> {AWOLNATION},
#  {AWOLNATION} -> {Dirty Heads},
#  {Ellie Goulding} -> {AWOLNATION},
#  {AWOLNATION} -> {Ellie Goulding},
#  {Fun.} -> {AWOLNATION},
#  {AWOLNATION} -> {Fun.},
#  {Grouplove} -> {AWOLNATION},
#  {AWOLNATION} -> {Grouplove},
#  {Imagine Dragons} -> {AWOLNATION},
#  {AWOLNATION} -> {Imagine Dragons},
#  {JAY Z} -> {AWOLNATION},
#  {AWOLNATION} -> {JAY Z},
#  {Justin Timberlake} -> {AWOLNATION},
#  {AWOLNATION} -> {Justin Timberlake},
#  {Katy Perry} -> {AWOLNATION},
#  {AWOLNATION} -> {Katy Perry},
#  {Kendrick Lamar} -> {AWOLNATION},
#  {AWOLNATION} -> {Kendrick Lamar},
#  {Macklemore & Ryan Lewis} -> {AWOLNATION},
#  {AWOLNATION} -> {Macklemore & Ryan Lewis},
#  {Milo Greene} -> {AWOLNATION},
#  {AWOLNATION} -> {Milo Greene},
#  {Of Monsters and Men} -> {AWOLNATION},
#  {AWOLNATION} -> {Of Monsters and Men},
#  {OneRepublic} -> {AWOLNATION},
#  {AWOLNATION} -> {OneRepublic},
#  {PSY} -> {AWOLNATION},
#  {AWOLNATION} -> {PSY},
#  {Regina Spektor} -> {AWOLNATION},
#  {AWOLNATION} -> {Regina Spektor},
#  {Rihanna} -> {AWOLNATION},
#  {AWOLNATION} -> {Rihanna},
#  {The Black Keys} -> {AWOLNATION},
#  {AWOLNATION} -> {The Black Keys},
#  {The Civil Wars} -> {AWOLNATION},
#  {AWOLNATION} -> {The Civil Wars},
#  {Jatin-Lalit} -> {Aadesh Shrivastava},
#  {Aadesh Shrivastava} -> {Jatin-Lalit},
#  {Sandesh Shandilya} -> {Aadesh Shrivastava},
#  {Aadesh Shrivastava} -> {Sandesh Shandilya},
#  {Shankar Ehsaan Loy} -> {Aadesh Shrivastava},
#  {Aadesh Shrivastava} -> {Shankar Ehsaan Loy},
#  {Ginuwine} -> {Aaliyah},
#  {Aaliyah} -> {Ginuwine},
#  {Joe} -> {Aaliyah},
#  {Aaliyah} -> {Joe},
#  {K-Ci & JoJo} -> {Aaliyah},
#  {Aaliyah} -> {K-Ci & JoJo},
#  {Snoop Dogg} -> {Aaliyah},
#  {Aaliyah} -> {Snoop Dogg},
#  {Usher} -> {Aaliyah},
#  {Aaliyah} -> {Usher},
#  {Samuel Barber} -> {Aaron Copland},
#  {Aaron Copland} -> {Samuel Barber},
#  {Ed Sheeran} -> {Aaron Lewis},
#  {Aaron Lewis} -> {Ed Sheeran},
#  {Jason Mraz} -> {Aaron Lewis},
#  {Aaron Lewis} -> {Jason Mraz},
#  {Sam Smith} -> {Aaron Lewis},
#  {Aaron Lewis} -> {Sam Smith},
#  {Miles Davis} -> {Aaron Neville},
#  {Aaron Neville} -> {Miles Davis},
#  {Sam Cooke} -> {Aaron Neville},
#  {Aaron Neville} -> {Sam Cooke},
#  {Anni B Sweet} -> {Aaron Thomas},
#  {Aaron Thomas} -> {Anni B Sweet},
#  {The Head And The Heart} -> {Aaron Thomas},
#  {Aaron Thomas} -> {The Head And The Heart},
#  {Zahara} -> {Aaron Thomas},
#  {Aaron Thomas} -> {Zahara},
#  {Alice Ripley} -> {Aaron Tveit},
#  {Aaron Tveit} -> {Alice Ripley},
#  {J. Robert Spencer} -> {Aaron Tveit},
#  {Aaron Tveit} -> {J. Robert Spencer},
#  {Jennifer Damiano} -> {Aaron Tveit},
#  {Aaron Tveit} -> {Jennifer Damiano},
#  {Louis Hobson} -> {Aaron Tveit},
#  {Aaron Tveit} -> {Louis Hobson},
#  {Next to Normal Band} -> {Aaron Tveit},
#  {Aaron Tveit} -> {Next to Normal Band},
#  {Black Hippy} -> {Ab-Soul},
#  {Ab-Soul} -> {Black Hippy},
#  {Isaiah Rashad} -> {Ab-Soul},
#  {Ab-Soul} -> {Isaiah Rashad},
#  {Jay Rock} -> {Ab-Soul},
#  {Ab-Soul} -> {Jay Rock},
#  {Kanye West} -> {Ab-Soul},
#  {Ab-Soul} -> {Kanye West},
#  {Kendrick Lamar} -> {Ab-Soul},
#  {Ab-Soul} -> {Kendrick Lamar},
#  {Schoolboy Q} -> {Ab-Soul},
#  {Ab-Soul} -> {Schoolboy Q},
#  {Alfredo Catalani} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Alfredo Catalani},
#  {Bernard Herrmann} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Bernard Herrmann},
#  {Booker T. & The MG's} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Booker T. & The MG's},
#  {Etta James} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Etta James},
#  {Jo Stafford} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Jo Stafford},
#  {Miriam Gauci} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Miriam Gauci},
#  {Shigeru Umebayashi} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Shigeru Umebayashi},
#  {Steve Cropper} -> {Abel Korzeniowski},
#  {Abel Korzeniowski} -> {Steve Cropper},
#  {Bally Sagoo, D. Khanne Wala, Hans Raj Hans} -> {Abhijeet and Anuradha Shriram},
#  {Abhijeet and Anuradha Shriram} -> {Bally Sagoo, D. Khanne Wala, Hans Raj Hans},
#  {Madan Bala Sindhu} -> {Abhijeet and Anuradha Shriram},
#  {Abhijeet and Anuradha Shriram} -> {Madan Bala Sindhu},
#  {Midival Punditz} -> {Abhijeet and Anuradha Shriram},
#  {Abhijeet and Anuradha Shriram} -> {Midival Punditz},
#  {Mohammed Rafi} -> {Abhijeet and Anuradha Shriram},
#  {Abhijeet and Anuradha Shriram} -> {Mohammed Rafi},
#  {Mychael Danna} -> {Abhijeet and Anuradha Shriram},
#  {Abhijeet and Anuradha Shriram} -> {Mychael Danna},
#  {Nusrat Fateh Ali Khan} -> {Abhijeet and Anuradha Shriram},
#  {Abhijeet and Anuradha Shriram} -> {Nusrat Fateh Ali Khan},
#  {Avicii} -> {Above & Beyond},
#  {Above & Beyond} -> {Avicii},
#  {Flowers and Sea Creatures} -> {Above & Beyond},
#  {Above & Beyond} -> {Flowers and Sea Creatures},
#  {London Grammar} -> {Above & Beyond},
#  {Above & Beyond} -> {London Grammar},
#  {Mat Zo} -> {Above & Beyond},
#  {Above & Beyond} -> {Mat Zo},
#  {Sponge} -> {Abra Moore},
#  {Abra Moore} -> {Sponge},
#  {Iron Maiden} -> {Accept},
#  {Accept} -> {Iron Maiden},
#  {BLF} -> {Acda en de Munnik},
#  {Acda en de Munnik} -> {BLF},
#  {De Poema's} -> {Acda en de Munnik},
#  {Acda en de Munnik} -> {De Poema's},
#  {Guus Meeuwis} -> {Acda en de Munnik},
#  {Acda en de Munnik} -> {Guus Meeuwis},
#  {Keizer & De Munnik} -> {Acda en de Munnik},
#  {Acda en de Munnik} -> {Keizer & De Munnik},
#  {Nick} -> {Acda en de Munnik},
#  {Acda en de Munnik} -> {Nick},
#  {Gene Simmons} -> {Ace Frehley},
#  {Ace Frehley} -> {Gene Simmons},
#  {KISS} -> {Ace Frehley},
#  {Ace Frehley} -> {KISS},
#  {Paul Stanley} -> {Ace Frehley},
#  {Ace Frehley} -> {Paul Stanley},
#  {Peter Criss} -> {Ace Frehley},
#  {Ace Frehley} -> {Peter Criss},
#  {Birdman} -> {Ace Hood},
#  {Ace Hood} -> {Birdman},
#  {DJ Khaled} -> {Ace Hood},
#  {Ace Hood} -> {DJ Khaled},
#  {Drake} -> {Ace Hood},
#  {Ace Hood} -> {Drake},
#  {Kanye West} -> {Ace Hood},
#  {Ace Hood} -> {Kanye West},
#  {Rick Ross} -> {Ace Hood},
#  {Ace Hood} -> {Rick Ross},
#  {Liquid Soul} -> {Ace Ventura},
#  {Ace Ventura} -> {Liquid Soul},
#  {Ellen Benediktson} -> {Ace Wilder},
#  {Ace Wilder} -> {Ellen Benediktson},
#  {Katy Perry} -> {Ace Wilder},
#  {Ace Wilder} -> {Katy Perry},
#  {Aqua} -> {Ace of Base},
#  {Ace of Base} -> {Aqua},
#  {Britney Spears} -> {Ace of Base},
#  {Ace of Base} -> {Britney Spears},
#  {Marky Mark And The Funky Bunch} -> {Ace of Base},
#  {Ace of Base} -> {Marky Mark And The Funky Bunch},
#  {Michael Jackson} -> {Ace of Base},
#  {Ace of Base} -> {Michael Jackson},
#  {Spice Girls} -> {Ace of Base},
#  {Ace of Base} -> {Spice Girls},
#  {TLC} -> {Ace of Base},
#  {Ace of Base} -> {TLC},
#  {Bethel Music} -> {Acoustic Worship Ensemble},
#  {Acoustic Worship Ensemble} -> {Bethel Music},
#  {J. Cole} -> {Action Bronson},
#  {Action Bronson} -> {J. Cole},
#  {JAY Z} -> {Action Bronson},
#  {Action Bronson} -> {JAY Z},
#  {Joey Bada$$} -> {Action Bronson},
#  {Action Bronson} -> {Joey Bada$$},
#  {Kanye West} -> {Action Bronson},
#  {Action Bronson} -> {Kanye West},
#  {Kendrick Lamar} -> {Action Bronson},
#  {Action Bronson} -> {Kendrick Lamar},
#  {Hannah Cohen} -> {Active Child},
#  {Active Child} -> {Hannah Cohen},
#  {Lanterns on the Lake} -> {Active Child},
#  {Active Child} -> {Lanterns on the Lake},
#  {M83} -> {Active Child},
#  {Active Child} -> {M83},
#  {Man Without Country} -> {Active Child},
#  {Active Child} -> {Man Without Country},
#  {Moby} -> {Active Child},
#  {Active Child} -> {Moby},
#  {School Of Seven Bells} -> {Active Child},
#  {Active Child} -> {School Of Seven Bells},
#  {Susanne Sundfr} -> {Active Child},
#  {Active Child} -> {Susanne Sundfr},
#  {The Archive} -> {Active Child},
#  {Active Child} -> {The Archive},
#  {Passenger} -> {Adam Cohen},
#  {Adam Cohen} -> {Passenger},
#  {Andrew Bird} -> {Adam Green},
#  {Adam Green} -> {Andrew Bird},
#  {Florence + The Machine} -> {Adam Green},
#  {Adam Green} -> {Florence + The Machine},
#  {The Dodos} -> {Adam Green},
#  {Adam Green} -> {The Dodos},
#  ...]

# %%
# test output of recommended artists
rules_rhs = filter(lambda rule: len(rule.lhs) == 1 and len(rule.rhs) == 1, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.confidence, reverse = True):
    if (rule.lhs == ("Kanye West", )) & (rule.lift > 1):
        print(rule)
# Out:
# {Kanye West} -> {JAY Z} (conf: 0.299, supp: 0.004, lift: 21.768, conv: 1.407)
# {Kanye West} -> {Drake} (conf: 0.134, supp: 0.002, lift: 15.294, conv: 1.144)
# {Kanye West} -> {Kid Cudi} (conf: 0.110, supp: 0.002, lift: 26.065, conv: 1.119)
# {Kanye West} -> {Eminem} (conf: 0.075, supp: 0.001, lift: 8.378, conv: 1.071)
# {Kanye West} -> {Beyonce} (conf: 0.067, supp: 0.001, lift: 5.726, conv: 1.059)
# {Kanye West} -> {John Legend} (conf: 0.063, supp: 0.001, lift: 12.326, conv: 1.062)
# {Kanye West} -> {Kendrick Lamar} (conf: 0.059, supp: 0.001, lift: 11.048, conv: 1.057)
# {Kanye West} -> {Big Sean} (conf: 0.051, supp: 0.001, lift: 22.929, conv: 1.052)
# {Kanye West} -> {Rihanna} (conf: 0.051, supp: 0.001, lift: 4.378, conv: 1.042)
# {Kanye West} -> {DJ Khaled} (conf: 0.047, supp: 0.001, lift: 25.945, conv: 1.048)
# {Kanye West} -> {Lupe Fiasco} (conf: 0.047, supp: 0.001, lift: 20.107, conv: 1.047)
# {Kanye West} -> {J. Cole} (conf: 0.043, supp: 0.001, lift: 21.684, conv: 1.043)
# {Kanye West} -> {The-Dream} (conf: 0.043, supp: 0.001, lift: 40.959, conv: 1.044)
# {Kanye West} -> {Lil Wayne} (conf: 0.039, supp: 0.001, lift: 11.556, conv: 1.037)
# {Kanye West} -> {Raekwon} (conf: 0.039, supp: 0.001, lift: 23.112, conv: 1.039)
# {Kanye West} -> {Rick Ross} (conf: 0.039, supp: 0.001, lift: 15.233, conv: 1.038)
# {Kanye West} -> {A$AP Rocky} (conf: 0.035, supp: 0.001, lift: 12.064, conv: 1.034)
# {Kanye West} -> {Snoop Dogg} (conf: 0.035, supp: 0.001, lift: 5.338, conv: 1.030)
# {Kanye West} -> {Daft Punk} (conf: 0.031, supp: 0.000, lift: 2.243, conv: 1.018)
# {Kanye West} -> {Nicki Minaj} (conf: 0.031, supp: 0.000, lift: 5.206, conv: 1.026)
# {Kanye West} -> {T.I.} (conf: 0.031, supp: 0.000, lift: 15.320, conv: 1.030)
# {Kanye West} -> {Twista} (conf: 0.031, supp: 0.000, lift: 33.512, conv: 1.032)
# {Kanye West} -> {Wiz Khalifa} (conf: 0.031, supp: 0.000, lift: 8.936, conv: 1.029)
# {Kanye West} -> {2Pac} (conf: 0.028, supp: 0.000, lift: 9.022, conv: 1.025)
# {Kanye West} -> {Calvin Harris} (conf: 0.028, supp: 0.000, lift: 3.192, conv: 1.019)
# {Kanye West} -> {David Guetta} (conf: 0.028, supp: 0.000, lift: 2.346, conv: 1.016)
# {Kanye West} -> {Iggy Azalea} (conf: 0.028, supp: 0.000, lift: 7.691, conv: 1.025)
# {Kanye West} -> {Macklemore & Ryan Lewis} (conf: 0.028, supp: 0.000, lift: 5.331, conv: 1.023)
# {Kanye West} -> {2 Chainz} (conf: 0.024, supp: 0.000, lift: 16.756, conv: 1.023)
# {Kanye West} -> {Arctic Monkeys} (conf: 0.024, supp: 0.000, lift: 3.591, conv: 1.017)
# {Kanye West} -> {Frank Ocean} (conf: 0.024, supp: 0.000, lift: 7.055, conv: 1.021)
# {Kanye West} -> {Justin Timberlake} (conf: 0.024, supp: 0.000, lift: 4.021, conv: 1.018)
# {Kanye West} -> {Ke$ha} (conf: 0.024, supp: 0.000, lift: 7.447, conv: 1.021)
# {Kanye West} -> {Mos Def} (conf: 0.024, supp: 0.000, lift: 13.405, conv: 1.022)
# {Kanye West} -> {Nas} (conf: 0.024, supp: 0.000, lift: 8.378, conv: 1.021)
# {Kanye West} -> {Pusha T} (conf: 0.024, supp: 0.000, lift: 17.484, conv: 1.023)
# {Kanye West} -> {The Notorious B.I.G.} (conf: 0.024, supp: 0.000, lift: 7.312, conv: 1.021)
# {Kanye West} -> {Adele} (conf: 0.020, supp: 0.000, lift: 2.992, conv: 1.013)
# {Kanye West} -> {B.o.B} (conf: 0.020, supp: 0.000, lift: 7.447, conv: 1.017)
# {Kanye West} -> {Childish Gambino} (conf: 0.020, supp: 0.000, lift: 8.593, conv: 1.018)
# {Kanye West} -> {Dr. Dre} (conf: 0.020, supp: 0.000, lift: 7.793, conv: 1.018)
# {Kanye West} -> {Jay-Z} (conf: 0.020, supp: 0.000, lift: 22.341, conv: 1.019)
# {Kanye West} -> {Katy Perry} (conf: 0.020, supp: 0.000, lift: 1.948, conv: 1.010)
# {Kanye West} -> {Mac Miller} (conf: 0.020, supp: 0.000, lift: 15.958, conv: 1.019)
# {Kanye West} -> {OutKast} (conf: 0.020, supp: 0.000, lift: 5.319, conv: 1.016)
# {Kanye West} -> {Avicii} (conf: 0.016, supp: 0.000, lift: 1.888, conv: 1.008)
# {Kanye West} -> {Black Star} (conf: 0.016, supp: 0.000, lift: 19.150, conv: 1.015)
# {Kanye West} -> {Bon Iver} (conf: 0.016, supp: 0.000, lift: 2.197, conv: 1.009)
# {Kanye West} -> {Chiddy Bang} (conf: 0.016, supp: 0.000, lift: 16.756, conv: 1.015)
# {Kanye West} -> {Earl Sweatshirt} (conf: 0.016, supp: 0.000, lift: 14.894, conv: 1.015)
# {Kanye West} -> {Fabolous} (conf: 0.016, supp: 0.000, lift: 17.873, conv: 1.015)
# {Kanye West} -> {Flo Rida} (conf: 0.016, supp: 0.000, lift: 2.793, conv: 1.010)
# {Kanye West} -> {Janelle Monae} (conf: 0.016, supp: 0.000, lift: 8.648, conv: 1.014)
# {Kanye West} -> {Jason Derulo} (conf: 0.016, supp: 0.000, lift: 4.395, conv: 1.012)
# {Kanye West} -> {Justin Bieber} (conf: 0.016, supp: 0.000, lift: 3.724, conv: 1.012)
# {Kanye West} -> {Lauryn Hill} (conf: 0.016, supp: 0.000, lift: 9.575, conv: 1.014)
# {Kanye West} -> {Major Lazer} (conf: 0.016, supp: 0.000, lift: 3.885, conv: 1.012)
# {Kanye West} -> {Michael Jackson} (conf: 0.016, supp: 0.000, lift: 1.665, conv: 1.006)
# {Kanye West} -> {Miley Cyrus} (conf: 0.016, supp: 0.000, lift: 3.724, conv: 1.012)
# {Kanye West} -> {Sleigh Bells} (conf: 0.016, supp: 0.000, lift: 8.124, conv: 1.014)
# {Kanye West} -> {Talib Kweli} (conf: 0.016, supp: 0.000, lift: 16.756, conv: 1.015)
# {Kanye West} -> {Wale} (conf: 0.016, supp: 0.000, lift: 9.245, conv: 1.014)
# {Kanye West} -> {Wu-Tang Clan} (conf: 0.016, supp: 0.000, lift: 8.648, conv: 1.014)
# {Kanye West} -> {Yeah Yeah Yeahs} (conf: 0.016, supp: 0.000, lift: 6.235, conv: 1.013)
# {Kanye West} -> {A Tribe Called Quest} (conf: 0.012, supp: 0.000, lift: 6.702, conv: 1.010)
# {Kanye West} -> {Ace Hood} (conf: 0.012, supp: 0.000, lift: 18.279, conv: 1.011)
# {Kanye West} -> {Action Bronson} (conf: 0.012, supp: 0.000, lift: 25.134, conv: 1.011)
# {Kanye West} -> {Akon} (conf: 0.012, supp: 0.000, lift: 11.828, conv: 1.011)
# {Kanye West} -> {Arcade Fire} (conf: 0.012, supp: 0.000, lift: 2.513, conv: 1.007)
# {Kanye West} -> {Beastie Boys} (conf: 0.012, supp: 0.000, lift: 3.408, conv: 1.008)
# {Kanye West} -> {Birdman} (conf: 0.012, supp: 0.000, lift: 28.724, conv: 1.012)
# {Kanye West} -> {Bob Marley & The Wailers} (conf: 0.012, supp: 0.000, lift: 2.285, conv: 1.007)
# {Kanye West} -> {Bobby Shmurda} (conf: 0.012, supp: 0.000, lift: 33.512, conv: 1.012)
# {Kanye West} -> {Bruno Mars} (conf: 0.012, supp: 0.000, lift: 2.285, conv: 1.007)
# {Kanye West} -> {Chief Keef} (conf: 0.012, supp: 0.000, lift: 40.214, conv: 1.012)
# {Kanye West} -> {Common} (conf: 0.012, supp: 0.000, lift: 6.702, conv: 1.010)
# {Kanye West} -> {Crystal Castles} (conf: 0.012, supp: 0.000, lift: 5.585, conv: 1.010)
# {Kanye West} -> {Diddy - Dirty Money} (conf: 0.012, supp: 0.000, lift: 25.134, conv: 1.011)
# {Kanye West} -> {Dilated Peoples} (conf: 0.012, supp: 0.000, lift: 25.134, conv: 1.011)
# {Kanye West} -> {Disclosure} (conf: 0.012, supp: 0.000, lift: 2.186, conv: 1.006)
# {Kanye West} -> {Ellie Goulding} (conf: 0.012, supp: 0.000, lift: 1.622, conv: 1.005)
# {Kanye West} -> {Estelle} (conf: 0.012, supp: 0.000, lift: 18.279, conv: 1.011)
# {Kanye West} -> {Fun.} (conf: 0.012, supp: 0.000, lift: 3.192, conv: 1.008)
# {Kanye West} -> {Guns N' Roses} (conf: 0.012, supp: 0.000, lift: 2.285, conv: 1.007)
# {Kanye West} -> {Icona Pop} (conf: 0.012, supp: 0.000, lift: 3.867, conv: 1.009)
# {Kanye West} -> {Lorde} (conf: 0.012, supp: 0.000, lift: 2.031, conv: 1.006)
# {Kanye West} -> {Lupe Fiasco feat. Nikki Jean} (conf: 0.012, supp: 0.000, lift: 40.214, conv: 1.012)
# {Kanye West} -> {Lykke Li} (conf: 0.012, supp: 0.000, lift: 3.351, conv: 1.008)
# {Kanye West} -> {MGMT} (conf: 0.012, supp: 0.000, lift: 3.142, conv: 1.008)
# {Kanye West} -> {N.E.R.D.} (conf: 0.012, supp: 0.000, lift: 10.054, conv: 1.011)
# {Kanye West} -> {Royksopp} (conf: 0.012, supp: 0.000, lift: 3.192, conv: 1.008)
# {Kanye West} -> {SBTRKT} (conf: 0.012, supp: 0.000, lift: 4.189, conv: 1.009)
# {Kanye West} -> {Sigur Ros} (conf: 0.012, supp: 0.000, lift: 2.452, conv: 1.007)
# {Kanye West} -> {Swedish House Mafia} (conf: 0.012, supp: 0.000, lift: 2.914, conv: 1.008)
# {Kanye West} -> {The Black Keys} (conf: 0.012, supp: 0.000, lift: 2.394, conv: 1.007)
# {Kanye West} -> {The National} (conf: 0.012, supp: 0.000, lift: 2.513, conv: 1.007)
# {Kanye West} -> {The Weeknd} (conf: 0.012, supp: 0.000, lift: 3.794, conv: 1.009)
# {Kanye West} -> {The xx} (conf: 0.012, supp: 0.000, lift: 1.952, conv: 1.006)
# {Kanye West} -> {Tinie Tempah} (conf: 0.012, supp: 0.000, lift: 8.742, conv: 1.011)
# {Kanye West} -> {Tyga} (conf: 0.012, supp: 0.000, lift: 8.742, conv: 1.011)
# {Kanye West} -> {Tyler, The Creator} (conf: 0.012, supp: 0.000, lift: 7.181, conv: 1.010)
# {Kanye West} -> {Usher} (conf: 0.012, supp: 0.000, lift: 3.724, conv: 1.009)
# {Kanye West} -> {WZRD} (conf: 0.012, supp: 0.000, lift: 67.024, conv: 1.012)
# {Kanye West} -> {Wilco} (conf: 0.012, supp: 0.000, lift: 3.943, conv: 1.009)
# {Kanye West} -> {YG} (conf: 0.012, supp: 0.000, lift: 22.341, conv: 1.011)
# {Kanye West} -> {ASTR} (conf: 0.008, supp: 0.000, lift: 26.809, conv: 1.008)
# {Kanye West} -> {Ab-Soul} (conf: 0.008, supp: 0.000, lift: 19.150, conv: 1.008)
# {Kanye West} -> {Azealia Banks} (conf: 0.008, supp: 0.000, lift: 6.383, conv: 1.007)
# {Kanye West} -> {Bassnectar} (conf: 0.008, supp: 0.000, lift: 6.093, conv: 1.007)
# {Kanye West} -> {Bastille} (conf: 0.008, supp: 0.000, lift: 1.943, conv: 1.004)
# {Kanye West} -> {Blink-182} (conf: 0.008, supp: 0.000, lift: 33.512, conv: 1.008)
# {Kanye West} -> {Bloc Party} (conf: 0.008, supp: 0.000, lift: 4.189, conv: 1.006)
# {Kanye West} -> {Bow Wow} (conf: 0.008, supp: 0.000, lift: 16.756, conv: 1.007)
# {Kanye West} -> {Chris Brown} (conf: 0.008, supp: 0.000, lift: 1.741, conv: 1.003)
# {Kanye West} -> {Clipse} (conf: 0.008, supp: 0.000, lift: 14.894, conv: 1.007)
# {Kanye West} -> {Coolio} (conf: 0.008, supp: 0.000, lift: 22.341, conv: 1.008)
# {Kanye West} -> {DJ Drama} (conf: 0.008, supp: 0.000, lift: 12.186, conv: 1.007)
# {Kanye West} -> {Deerhunter} (conf: 0.008, supp: 0.000, lift: 8.378, conv: 1.007)
# {Kanye West} -> {Deftones} (conf: 0.008, supp: 0.000, lift: 4.189, conv: 1.006)
# {Kanye West} -> {Dimitri Vegas} (conf: 0.008, supp: 0.000, lift: 11.171, conv: 1.007)
# {Kanye West} -> {Dirty Money} (conf: 0.008, supp: 0.000, lift: 67.024, conv: 1.008)
# {Kanye West} -> {Eminem Featuring P!nk} (conf: 0.008, supp: 0.000, lift: 19.150, conv: 1.008)
# {Kanye West} -> {Fall Out Boy} (conf: 0.008, supp: 0.000, lift: 1.836, conv: 1.004)
# {Kanye West} -> {Feist} (conf: 0.008, supp: 0.000, lift: 2.628, conv: 1.005)
# {Kanye West} -> {Flight Facilities} (conf: 0.008, supp: 0.000, lift: 4.965, conv: 1.006)
# {Kanye West} -> {Florence + The Machine} (conf: 0.008, supp: 0.000, lift: 1.314, conv: 1.002)
# {Kanye West} -> {Foo Fighters} (conf: 0.008, supp: 0.000, lift: 1.354, conv: 1.002)
# {Kanye West} -> {Fort Minor} (conf: 0.008, supp: 0.000, lift: 11.171, conv: 1.007)
# {Kanye West} -> {Foster The People} (conf: 0.008, supp: 0.000, lift: 1.862, conv: 1.004)
# {Kanye West} -> {Frank Sinatra} (conf: 0.008, supp: 0.000, lift: 1.117, conv: 1.001)
# {Kanye West} -> {French Montana} (conf: 0.008, supp: 0.000, lift: 13.405, conv: 1.007)
# {Kanye West} -> {Fugees} (conf: 0.008, supp: 0.000, lift: 6.702, conv: 1.007)
# {Kanye West} -> {Future} (conf: 0.008, supp: 0.000, lift: 14.894, conv: 1.007)
# {Kanye West} -> {Future Islands} (conf: 0.008, supp: 0.000, lift: 4.787, conv: 1.006)
# {Kanye West} -> {Gang Starr} (conf: 0.008, supp: 0.000, lift: 4.965, conv: 1.006)
# {Kanye West} -> {Ghostface Killah} (conf: 0.008, supp: 0.000, lift: 5.828, conv: 1.007)
# {Kanye West} -> {Gorillaz} (conf: 0.008, supp: 0.000, lift: 1.888, conv: 1.004)
# {Kanye West} -> {Hakan Hellstrom} (conf: 0.008, supp: 0.000, lift: 5.156, conv: 1.006)
# {Kanye West} -> {Hudson Mohawke} (conf: 0.008, supp: 0.000, lift: 10.311, conv: 1.007)
# {Kanye West} -> {James Blake} (conf: 0.008, supp: 0.000, lift: 1.811, conv: 1.004)
# {Kanye West} -> {Jeezy} (conf: 0.008, supp: 0.000, lift: 12.186, conv: 1.007)
# {Kanye West} -> {John Grant} (conf: 0.008, supp: 0.000, lift: 9.575, conv: 1.007)
# {Kanye West} -> {John Mayer} (conf: 0.008, supp: 0.000, lift: 1.301, conv: 1.002)
# {Kanye West} -> {Journey} (conf: 0.008, supp: 0.000, lift: 3.437, conv: 1.006)
# {Kanye West} -> {Justice} (conf: 0.008, supp: 0.000, lift: 2.394, conv: 1.005)
# {Kanye West} -> {Keri Hilson} (conf: 0.008, supp: 0.000, lift: 13.405, conv: 1.007)
# {Kanye West} -> {KiD CuDi} (conf: 0.008, supp: 0.000, lift: 26.809, conv: 1.008)
# {Kanye West} -> {Kid Ink} (conf: 0.008, supp: 0.000, lift: 11.171, conv: 1.007)
# {Kanye West} -> {Kurt Vile} (conf: 0.008, supp: 0.000, lift: 6.702, conv: 1.007)
# {Kanye West} -> {LMFAO} (conf: 0.008, supp: 0.000, lift: 2.736, conv: 1.005)
# {Kanye West} -> {Lady Gaga} (conf: 0.008, supp: 0.000, lift: 1.208, conv: 1.001)
# {Kanye West} -> {Lil Durk} (conf: 0.008, supp: 0.000, lift: 26.809, conv: 1.008)
# {Kanye West} -> {Lil Jon} (conf: 0.008, supp: 0.000, lift: 14.894, conv: 1.007)
# {Kanye West} -> {Los Campesinos!} (conf: 0.008, supp: 0.000, lift: 8.378, conv: 1.007)
# {Kanye West} -> {Louis Armstrong} (conf: 0.008, supp: 0.000, lift: 1.943, conv: 1.004)
# {Kanye West} -> {Lupe Fiasco feat. Snoop Dogg and Pooh Bear} (conf: 0.008, supp: 0.000, lift: 33.512, conv: 1.008)
# {Kanye West} -> {M.I.A.} (conf: 0.008, supp: 0.000, lift: 2.352, conv: 1.005)
# {Kanye West} -> {MGK} (conf: 0.008, supp: 0.000, lift: 22.341, conv: 1.008)
# {Kanye West} -> {Mase} (conf: 0.008, supp: 0.000, lift: 44.682, conv: 1.008)
# {Kanye West} -> {Meghan Trainor} (conf: 0.008, supp: 0.000, lift: 2.578, conv: 1.005)
# {Kanye West} -> {Memphis Bleek} (conf: 0.008, supp: 0.000, lift: 44.682, conv: 1.008)
# {Kanye West} -> {Mobb Deep} (conf: 0.008, supp: 0.000, lift: 7.055, conv: 1.007)
# {Kanye West} -> {Modest Mouse} (conf: 0.008, supp: 0.000, lift: 2.914, conv: 1.005)
# {Kanye West} -> {Mumford & Sons} (conf: 0.008, supp: 0.000, lift: 1.031, conv: 1.000)
# {Kanye West} -> {Ne-Yo} (conf: 0.008, supp: 0.000, lift: 4.787, conv: 1.006)
# {Kanye West} -> {Neil Young} (conf: 0.008, supp: 0.000, lift: 2.001, conv: 1.004)
# {Kanye West} -> {O.T. Genasis} (conf: 0.008, supp: 0.000, lift: 26.809, conv: 1.008)
# {Kanye West} -> {Oasis} (conf: 0.008, supp: 0.000, lift: 2.352, conv: 1.005)
# {Kanye West} -> {Orbital} (conf: 0.008, supp: 0.000, lift: 6.093, conv: 1.007)
# {Kanye West} -> {P!nk} (conf: 0.008, supp: 0.000, lift: 1.971, conv: 1.004)
# {Kanye West} -> {Panic! At The Disco} (conf: 0.008, supp: 0.000, lift: 3.117, conv: 1.005)
# {Kanye West} -> {Pharrell Williams} (conf: 0.008, supp: 0.000, lift: 1.411, conv: 1.002)
# {Kanye West} -> {Phil Collins} (conf: 0.008, supp: 0.000, lift: 3.269, conv: 1.006)
# {Kanye West} -> {Pitbull} (conf: 0.008, supp: 0.000, lift: 1.277, conv: 1.002)
# {Kanye West} -> {Rae Sremmurd} (conf: 0.008, supp: 0.000, lift: 11.171, conv: 1.007)
# {Kanye West} -> {Rage Against The Machine} (conf: 0.008, supp: 0.000, lift: 2.128, conv: 1.004)
# {Kanye West} -> {Red Hot Chili Peppers} (conf: 0.008, supp: 0.000, lift: 1.836, conv: 1.004)
# {Kanye West} -> {Rich Gang} (conf: 0.008, supp: 0.000, lift: 22.341, conv: 1.008)
# {Kanye West} -> {Robin Thicke} (conf: 0.008, supp: 0.000, lift: 2.437, conv: 1.005)
# {Kanye West} -> {Shaggy} (conf: 0.008, supp: 0.000, lift: 9.575, conv: 1.007)
# {Kanye West} -> {Shaun Reynolds feat. Laura Pringle} (conf: 0.008, supp: 0.000, lift: 22.341, conv: 1.008)
# {Kanye West} -> {Sia} (conf: 0.008, supp: 0.000, lift: 1.635, conv: 1.003)
# {Kanye West} -> {Skrillex} (conf: 0.008, supp: 0.000, lift: 1.523, conv: 1.003)
# {Kanye West} -> {Soulja Boy} (conf: 0.008, supp: 0.000, lift: 16.756, conv: 1.007)
# {Kanye West} -> {Sufjan Stevens} (conf: 0.008, supp: 0.000, lift: 1.559, conv: 1.003)
# {Kanye West} -> {T-Pain} (conf: 0.008, supp: 0.000, lift: 12.186, conv: 1.007)
# {Kanye West} -> {The Game} (conf: 0.008, supp: 0.000, lift: 4.622, conv: 1.006)
# {Kanye West} -> {The Gym Allstars} (conf: 0.008, supp: 0.000, lift: 67.024, conv: 1.008)
# {Kanye West} -> {The Lumineers} (conf: 0.008, supp: 0.000, lift: 2.162, conv: 1.004)
# {Kanye West} -> {The Roots} (conf: 0.008, supp: 0.000, lift: 3.437, conv: 1.006)
# {Kanye West} -> {The Strokes} (conf: 0.008, supp: 0.000, lift: 2.529, conv: 1.005)
# {Kanye West} -> {Theophilus London} (conf: 0.008, supp: 0.000, lift: 10.311, conv: 1.007)
# {Kanye West} -> {Timbaland} (conf: 0.008, supp: 0.000, lift: 3.830, conv: 1.006)
# {Kanye West} -> {Tove Lo} (conf: 0.008, supp: 0.000, lift: 2.914, conv: 1.005)
# {Kanye West} -> {Trey Songz} (conf: 0.008, supp: 0.000, lift: 3.623, conv: 1.006)
# {Kanye West} -> {Washed Out} (conf: 0.008, supp: 0.000, lift: 4.965, conv: 1.006)
# {Kanye West} -> {Yeezy} (conf: 0.008, supp: 0.000, lift: 67.024, conv: 1.008)
# {Kanye West} -> {a-ha} (conf: 0.008, supp: 0.000, lift: 5.585, conv: 1.007)
# {Kanye West} -> {will.i.am} (conf: 0.008, supp: 0.000, lift: 1.915, conv: 1.004)

# %% [markdown]
# ## Tests

# %%
# https://github.com/tommyod/Efficient-Apriori

from efficient_apriori.rules import (
    Rule,
    generate_rules_simple,
    generate_rules_apriori,
)
from efficient_apriori.itemsets import itemsets_from_transactions, ItemsetCount
import unittest 

# running the aprioi algorithm with a small subset of playlists 
listArtist_test = (['Justin Timberlake', 'One Direction', 'will.i.am', 'Disclosure'], 
                   ['5 Seconds of Summer', 'NSYNC', 'One Direction'])
min_support_test = 1/len(listArtist_test) 
min_confidence_test = 0
itemsets_subset, rules_subset = apriori(listArtist_test, min_support=min_support_test, min_confidence=min_confidence_test, 
                                       output_transaction_ids=True)

# defining a rule
r = Rule(('Harry Styles', 'Niall Horan'), ('One Direction',), 75, 100, 125, 250)
r2 = Rule(('Jay-Z', 'Tyler, The Creator', 'Kanye West'), ('Frank Ocean', "Pharrell Williams"), 25, 125, 150, 200)

# tests to ensure the output of the algorithm matches expectations on a subset of the data (one artist)
class TestOutput(unittest.TestCase):
    
    def test_output_subset(self):
        # counts of how many times each artist appears in the first iteration of an itemset, and which playlists they're in
        self.assertEqual(itemsets_subset[1], {('Justin Timberlake',): ItemsetCount(itemset_count=1, members={0}),
                                          ('One Direction',): ItemsetCount(itemset_count=2, members={0, 1}),
                                          ('will.i.am',): ItemsetCount(itemset_count=1, members={0}),
                                          ('Disclosure',): ItemsetCount(itemset_count=1, members={0}),
                                          ('5 Seconds of Summer',): ItemsetCount(itemset_count=1, members={1}),
                                          ('NSYNC',): ItemsetCount(itemset_count=1, members={1})})

    # test lhs and rhs rule functions
    def test_rule_functions(self):
        self.assertEqual(r.lhs, ('Harry Styles', 'Niall Horan'))
        self.assertEqual(r.rhs, ('One Direction',))
        self.assertEqual(r.confidence, 0.75)
        self.assertEqual(r2.lhs, ('Jay-Z', 'Tyler, The Creator', 'Kanye West'))
        self.assertEqual(r2.rhs, ('Frank Ocean', "Pharrell Williams"))
        self.assertEqual(r2.confidence, 0.2)
        self.assertEqual(r, Rule(('Harry Styles', 'Niall Horan'), ('One Direction',)))
        self.assertEqual(r2, Rule(('Jay-Z', 'Tyler, The Creator', 'Kanye West'), ('Frank Ocean', 'Pharrell Williams')))

# run tests
res = unittest.main(argv = [''], verbosity = 3, exit = False)
assert len(res.result.failures) == 0
# Out:
# test_output_subset (__main__.TestOutput) ... ok
# test_rule_functions (__main__.TestOutput) ... ok
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.004s
#
# OK

# %% [markdown]
# ## GUI Implementation

# %%
import matplotlib
matplotlib.use('Agg')
import tkinter
from tkinter import *

# https://www.geeksforgeeks.org/python-gui-tkinter/
# https://tkdocs.com/pyref/stringvar.html

master = Tk()
master.title('Recommender')

# defining canvas dimensions
canvas = Canvas(master, width = 300, height = 10)
canvas.pack()

# adding a label to the canvas
label = Label(master, text = 'Type in the name of a musical artist')
label.pack()

# collecting user input
var = StringVar()
   
entry = Entry(master, textvariable = var)
entry.focus_set()
entry.pack()

# adding a button to submit to the canvas
button = Button(master, text = 'Submit', width = 25, command = master.destroy)
button.pack()

master.mainloop()

# gather recommended artists from the algorithm
recommended = list()
rules_rhs = filter(lambda rule: len(rule.lhs) == 1 and len(rule.rhs) == 1, rules)
for rule in sorted(rules_rhs, key = lambda rule: rule.confidence, reverse = True):
    if (rule.lhs == (var.get(), )) & (rule.lift > 1):
        recommended.append(rule.rhs[0])
        print(rule)
        
# compile recommendations into a string
recommendations = ""
if len(recommended) < 5:
    for i in range(len(recommended)):
        recommendations = recommendations + recommended[i] + '\n'
else:
    for i in range(5):
        recommendations = recommendations + recommended[i] + '\n'

# printing out the recommendations or an error message if artist does not exist
if len(recommended) > 0:
    output = Tk()
    output.title('Recommender')
    canvas2 = Canvas(output, width = 500, height = 10)
    canvas2.pack()
    w = Label(output, text = "Recommendations:" + "\n" + recommendations)
    w.pack()
    output.mainloop()
else: 
    output = Tk()
    output.title('Error')
    w = Label(output, text = "Sorry that artist does not exist in our database. Please exit try a new artist."
    w.pack()
    output.mainloop()
